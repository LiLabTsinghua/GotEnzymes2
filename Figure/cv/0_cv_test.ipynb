# %%
import pandas as pd

# 定义文件路径
file_paths = {
    'KCAT': {
        'cv0': 'all_result_KCAT_cv0.txt',
        'cv1': 'all_result_KCAT_cv1.txt',
        'cv2': 'all_result_KCAT_cv2.txt',
        'cv3': 'all_result_KCAT_cv3.txt',
        'cv4': 'all_result_KCAT_cv4.txt'
    },
    'KM': {
        'cv0': 'all_result_KM_cv0.txt',
        'cv1': 'all_result_KM_cv1.txt',
        'cv2': 'all_result_KM_cv2.txt',
        'cv3': 'all_result_KM_cv3.txt',
        'cv4': 'all_result_KM_cv4.txt'
    },
    'KKM': {
        'cv0': 'all_result_KKM_cv0.txt',
        'cv1': 'all_result_KKM_cv1.txt',
        'cv2': 'all_result_KKM_cv2.txt',
        'cv3': 'all_result_KKM_cv3.txt',
        'cv4': 'all_result_KKM_cv4.txt'
    }
}

def process_file(file_path, suffix):
    """
    处理单个文件，提取模型名称和R²值，并去掉后缀。
    """
    with open(file_path, 'r') as file:
        lines = file.readlines()

    data = []
    for i in range(0, len(lines), 2):  # 每次跳两行
        model_line = lines[i].strip()  # 模型名称行
        metric_line = lines[i + 1].strip()  # 性能指标行

        # 提取模型名称并去掉后缀
        model_name = model_line.replace('./', '').replace('.csv', '').replace(suffix, '')

        # 提取R²值
        r2_value = None
        r2_index = metric_line.find('r2:')  # 找到'r2:'的位置
        if r2_index != -1:  # 如果找到'r2:'
            r2_str = metric_line[r2_index + 3:].strip()  # 提取'r2:'后面的部分并去掉空格
            if r2_str:  # 检查是否为空字符串
                try:
                    r2_value = float(r2_str)  # 尝试转换为浮点数
                except ValueError:
                    print(f"Warning: Could not convert R² value '{r2_str}' to float for model {model_name}")

        if r2_value is not None:
            data.append((model_name, r2_value))

    # 创建DataFrame
    df = pd.DataFrame(data, columns=['Model', 'R2'])

    return df

# 初始化存储每个类型的 R² 值的字典
type_r2_data = {
    'KCAT': {},
    'KM': {},
    'KKM': {}
}

# 处理每个文件
for file_type, cv_files in file_paths.items():
    for cv, file_path in cv_files.items():
        # 提取后缀（如 '_KCAT'）
        suffix = f'_{file_type}'
        # 处理文件
        df = process_file(file_path, suffix)
        # 将结果存储到 type_r2_data 中
        for _, row in df.iterrows():
            model = row['Model']
            r2 = row['R2']
            if model not in type_r2_data[file_type]:
                type_r2_data[file_type][model] = []
            type_r2_data[file_type][model].append(r2)

# 计算每个类型的 R² 均值并排序
results = {}
for file_type, models_r2 in type_r2_data.items():
    # 计算每个模型的 R² 均值
    mean_r2 = {model: sum(r2_list) / len(r2_list) for model, r2_list in models_r2.items()}
    # 创建 DataFrame
    df_mean_r2 = pd.DataFrame(list(mean_r2.items()), columns=['Model', 'Mean R2'])
    # 按 R² 均值排序并计算排名
    df_mean_r2 = df_mean_r2.sort_values(by='Mean R2', ascending=False)
    df_mean_r2['Rank'] = df_mean_r2['Mean R2'].rank(ascending=False, method='min')
    # 存储结果
    results[file_type] = df_mean_r2
# print(models_r2)
# 打印结果
for file_type, df in results.items():
    print(f"Results for {file_type}:")
    print(df)
    print("\n")
type_r2_data
# Out:
# Results for KCAT:
#                   Model   Mean R2  Rank
# 32        unimolv2_esmc  0.688272   1.0
# 7       unimolv2_prott5  0.686004   2.0
# 39        molebert_esmc  0.684448   3.0
# 10    chemberta2_prott5  0.684179   4.0
# 33       unimolv2_esm1b  0.683986   5.0
# 1       molebert_prott5  0.683535   6.0
# 16      chemberta2_esmc  0.683284   7.0
# 14          molgen_esmc  0.683021   8.0
# 13        unimolv2_esm2  0.682458   9.0
# 27     chemberta2_esm1b  0.682409  10.0
# 36          ecfp_prott5  0.682327  11.0
# 31        unimolv1_esmc  0.681507  12.0
# 18            ecfp_esmc  0.680119  13.0
# 29       molebert_esm1b  0.680102  14.0
# 23        molebert_esm2  0.679999  15.0
# 34         molgen_esm1b  0.679793  16.0
# 28      chemberta2_esm2  0.679408  17.0
# 21       unimolv1_esm1b  0.678745  18.0
# 4         molgen_prott5  0.678709  19.0
# 2       unimolv1_prott5  0.678258  20.0
# 38          molgen_esm2  0.677372  21.0
# 37        smitrans_esmc  0.676903  22.0
# 11           ecfp_esm1b  0.676823  23.0
# 42            ecfp_esm2  0.676817  24.0
# 25        unimolv1_esm2  0.676692  25.0
# 9       smitrans_prott5  0.673676  26.0
# 41       smitrans_esm1b  0.672888  27.0
# 12        smitrans_esm2  0.672053  28.0
# 35         rdkitfp_esmc  0.662942  29.0
# 20       rdkitfp_prott5  0.658927  30.0
# 0         rdkitfp_esm1b  0.657762  31.0
# 17         rdkitfp_esm2  0.657510  32.0
# 26     maccskeys_prott5  0.651925  33.0
# 43       maccskeys_esmc  0.651777  34.0
# 5       maccskeys_esm1b  0.649333  35.0
# 44       maccskeys_esm2  0.647523  36.0
# 30    molebert_prollama  0.641246  37.0
# 15    unimolv2_prollama  0.632739  38.0
# 22  chemberta2_prollama  0.631830  39.0
# 3         ecfp_prollama  0.631646  40.0
# 19    unimolv1_prollama  0.626332  41.0
# 6       molgen_prollama  0.621488  42.0
# 8     smitrans_prollama  0.618304  43.0
# 24     rdkitfp_prollama  0.609909  44.0
# 40   maccskeys_prollama  0.600968  45.0
#
#
# Results for KM:
#                   Model   Mean R2  Rank
# 7       unimolv2_prott5  0.665471   1.0
# 2        unimolv2_esm1b  0.664192   2.0
# 28       smitrans_esm1b  0.662510   3.0
# 23      smitrans_prott5  0.662298   4.0
# 25      molebert_prott5  0.662031   5.0
# 17        molgen_prott5  0.661539   6.0
# 30        unimolv2_esm2  0.660894   7.0
# 0        molebert_esm1b  0.660553   8.0
# 21         molgen_esm1b  0.659857   9.0
# 6           molgen_esm2  0.658418  10.0
# 34        smitrans_esm2  0.658237  11.0
# 26      unimolv1_prott5  0.658094  12.0
# 3     chemberta2_prott5  0.657829  13.0
# 15     chemberta2_esm1b  0.657537  14.0
# 9         unimolv2_esmc  0.657376  15.0
# 14       unimolv1_esm1b  0.657340  16.0
# 40        molebert_esm2  0.657128  17.0
# 24        smitrans_esmc  0.656661  18.0
# 36          molgen_esmc  0.655997  19.0
# 27      chemberta2_esm2  0.655434  20.0
# 20        molebert_esmc  0.654684  21.0
# 12        unimolv1_esm2  0.654662  22.0
# 41        unimolv1_esmc  0.651735  23.0
# 11      chemberta2_esmc  0.651516  24.0
# 29          ecfp_prott5  0.647693  25.0
# 1            ecfp_esm1b  0.647320  26.0
# 35            ecfp_esm2  0.642655  27.0
# 13            ecfp_esmc  0.640844  28.0
# 16        rdkitfp_esm1b  0.637654  29.0
# 19       rdkitfp_prott5  0.637291  30.0
# 37    unimolv2_prollama  0.636659  31.0
# 38    smitrans_prollama  0.636233  32.0
# 18     maccskeys_prott5  0.634495  33.0
# 43      maccskeys_esm1b  0.634386  34.0
# 33      molgen_prollama  0.633432  35.0
# 10    molebert_prollama  0.632582  36.0
# 5          rdkitfp_esm2  0.631748  37.0
# 42       maccskeys_esm2  0.631341  38.0
# 22  chemberta2_prollama  0.629224  39.0
# 39         rdkitfp_esmc  0.627483  40.0
# 4     unimolv1_prollama  0.627426  41.0
# 44       maccskeys_esmc  0.625380  42.0
# 32        ecfp_prollama  0.612797  43.0
# 31     rdkitfp_prollama  0.600629  44.0
# 8    maccskeys_prollama  0.595468  45.0
#
#
# Results for KKM:
#                   Model   Mean R2  Rank
# 9       molebert_prott5  0.599937   1.0
# 17        molebert_esmc  0.596343   2.0
# 24       molebert_esm1b  0.595955   3.0
# 8       unimolv1_prott5  0.595886   4.0
# 27       unimolv1_esm1b  0.595862   5.0
# 37      unimolv2_prott5  0.595427   6.0
# 20        molgen_prott5  0.593857   7.0
# 12        molebert_esm2  0.593834   8.0
# 16        unimolv1_esmc  0.593817   9.0
# 40         molgen_esm1b  0.593693  10.0
# 43        unimolv1_esm2  0.592270  11.0
# 41       unimolv2_esm1b  0.591957  12.0
# 4           molgen_esmc  0.591447  13.0
# 42      smitrans_prott5  0.588732  14.0
# 15        smitrans_esmc  0.588524  15.0
# 19        unimolv2_esmc  0.588497  16.0
# 6         unimolv2_esm2  0.588460  17.0
# 34          molgen_esm2  0.587510  18.0
# 35        smitrans_esm2  0.585523  19.0
# 30       smitrans_esm1b  0.584740  20.0
# 7     chemberta2_prott5  0.583576  21.0
# 33      chemberta2_esmc  0.580373  22.0
# 39     chemberta2_esm1b  0.579970  23.0
# 3       chemberta2_esm2  0.578811  24.0
# 2           ecfp_prott5  0.577295  25.0
# 1            ecfp_esm1b  0.572692  26.0
# 11            ecfp_esmc  0.569819  27.0
# 21            ecfp_esm2  0.568063  28.0
# 44       rdkitfp_prott5  0.561630  29.0
# 29     maccskeys_prott5  0.561348  30.0
# 38    molebert_prollama  0.556493  31.0
# 23      maccskeys_esm1b  0.555530  32.0
# 5         rdkitfp_esm1b  0.554687  33.0
# 28         rdkitfp_esmc  0.552862  34.0
# 25       maccskeys_esmc  0.551965  35.0
# 14         rdkitfp_esm2  0.551589  36.0
# 36       maccskeys_esm2  0.549374  37.0
# 32    unimolv1_prollama  0.549108  38.0
# 31      molgen_prollama  0.548628  39.0
# 13    unimolv2_prollama  0.545456  40.0
# 0     smitrans_prollama  0.539358  41.0
# 18  chemberta2_prollama  0.532028  42.0
# 10        ecfp_prollama  0.528892  43.0
# 26   maccskeys_prollama  0.512287  44.0
# 22     rdkitfp_prollama  0.510962  45.0
# {'KCAT': {'rdkitfp_esm1b': [0.6534576772940399,
#    0.6685847997687141,
#    0.6677909135418898,
#    0.6504343024174565,
#    0.6485445792766384],
#   'molebert_prott5': [0.6879731434131401,
#    0.6881043681511636,
#    0.6895752140331182,
#    0.6768772893984878,
#    0.6751444140220295],
#   'unimolv1_prott5': [0.6784466264762907,
#    0.6829957800083677,
#    0.68207755816972,
#    0.6761871793195445,
#    0.6715833287222719],
#   'ecfp_prollama': [0.6314149000446794,
#    0.6452956117162864,
#    0.627760097514554,
#    0.6239219034614929,
#    0.6298357272981581],
#   'molgen_prott5': [0.6845285057819588,
#    0.6813479560411171,
#    0.6769275742173078,
#    0.680276865477803,
#    0.6704623409050932],
#   'maccskeys_esm1b': [0.651399315260256,
#    0.6575254834159037,
#    0.6531641312481382,
#    0.6429563460652662,
#    0.6416185090122029],
#   'molgen_prollama': [0.6157287931427279,
#    0.6252957458452372,
#    0.6185633260705713,
#    0.6223577286039528,
#    0.625496582774633],
#   'unimolv2_prott5': [0.6847453906759576,
#    0.687681447425627,
#    0.6926445971468997,
#    0.6871370073500623,
#    0.6778120538243403],
#   'smitrans_prollama': [0.6144703250666644,
#    0.6269666356378023,
#    0.6133411241509934,
#    0.6202709548712136,
#    0.6164694062810702],
#   'smitrans_prott5': [0.676045491259772,
#    0.6791509234582808,
#    0.6732446711177172,
#    0.6725135104050445,
#    0.6674242785112604],
#   'chemberta2_prott5': [0.6875112200480256,
#    0.6847722180612409,
#    0.691314798430767,
#    0.6817839599096407,
#    0.6755113489971105],
#   'ecfp_esm1b': [0.6763121892955761,
#    0.6862034273759556,
#    0.6806966437524089,
#    0.6736733377678152,
#    0.6672299163943372],
#   'smitrans_esm2': [0.6721114388837104,
#    0.6800203410760729,
#    0.6728719282148481,
#    0.6723715623882476,
#    0.6628917411095177],
#   'unimolv2_esm2': [0.6817511299061317,
#    0.6820869292172097,
#    0.6889494009478525,
#    0.6870880937569455,
#    0.672414910725798],
#   'molgen_esmc': [0.6887069962904838,
#    0.6810364295068112,
#    0.6856563438587402,
#    0.6816793915583101,
#    0.6780258566602501],
#   'unimolv2_prollama': [0.6243358901268903,
#    0.6331798937228359,
#    0.6326542338408457,
#    0.6373936000223801,
#    0.636132680986895],
#   'chemberta2_esmc': [0.6879459263097876,
#    0.6803566047477585,
#    0.6873588670156516,
#    0.6815536717545412,
#    0.6792027418186197],
#   'rdkitfp_esm2': [0.6546896193302243,
#    0.6689532002916604,
#    0.6667145540490108,
#    0.6494897981350087,
#    0.6477005153960844],
#   'ecfp_esmc': [0.681581750250146,
#    0.6861581900239465,
#    0.6852104915960109,
#    0.6729809172279486,
#    0.6746620940718409],
#   'unimolv1_prollama': [0.6227937649619218,
#    0.6311908555093546,
#    0.6295204060073731,
#    0.6258936498846377,
#    0.622260407467671],
#   'rdkitfp_prott5': [0.6558718018354872,
#    0.6709801381848136,
#    0.6673738207822797,
#    0.6507647675625898,
#    0.6496451827382632],
#   'unimolv1_esm1b': [0.67897460571022,
#    0.6843800028955056,
#    0.6825376373916128,
#    0.6770695579514376,
#    0.6707634864894896],
#   'chemberta2_prollama': [0.6291813849993189,
#    0.6344397594752172,
#    0.63262279739989,
#    0.6314610811338756,
#    0.6314466346086993],
#   'molebert_esm2': [0.6811725616252406,
#    0.6883749231794445,
#    0.6831216222968619,
#    0.6732780377547032,
#    0.6740496837790677],
#   'rdkitfp_prollama': [0.596719740118867,
#    0.6168571507633072,
#    0.6181907714937805,
#    0.604560733850044,
#    0.6132181129546505],
#   'unimolv1_esm2': [0.6739961775621197,
#    0.6829205081902361,
#    0.6827106165569734,
#    0.6765292715129112,
#    0.6673053500592874],
#   'maccskeys_prott5': [0.6550652079670656,
#    0.658552048169842,
#    0.6544948513348341,
#    0.6452045388305172,
#    0.6463079222163652],
#   'chemberta2_esm1b': [0.6850202512236925,
#    0.6865647478004178,
#    0.6870086497756209,
#    0.6817321768514524,
#    0.671721546267973],
#   'chemberta2_esm2': [0.6800194625005878,
#    0.6817992973265523,
#    0.6845339164590688,
#    0.6808608106625595,
#    0.6698261189232716],
#   'molebert_esm1b': [0.6837481577478275,
#    0.6860990242706916,
#    0.6851258028745582,
#    0.6726821851023433,
#    0.6728567608981518],
#   'molebert_prollama': [0.6349998397210166,
#    0.6459297539942176,
#    0.6473642392201444,
#    0.6400251801961243,
#    0.6379124324779054],
#   'unimolv1_esmc': [0.6850070591164819,
#    0.6800109158494738,
#    0.689458981887052,
#    0.6767478642644642,
#    0.6763095500279682],
#   'unimolv2_esmc': [0.6902084358590519,
#    0.685734628665791,
#    0.6956239070200705,
#    0.6871886825911052,
#    0.6826021166526159],
#   'unimolv2_esm1b': [0.6857886778680486,
#    0.6856405096038396,
#    0.689110622619894,
#    0.6872504690898695,
#    0.6721402492511795],
#   'molgen_esm1b': [0.6861428847906641,
#    0.6828976616413022,
#    0.6770098981329882,
#    0.6819880609804684,
#    0.6709246471158159],
#   'rdkitfp_esmc': [0.6638598056123534,
#    0.6688030641420553,
#    0.6709063082047333,
#    0.6520983713880473,
#    0.659040328736627],
#   'ecfp_prott5': [0.6820674153809525,
#    0.6929307509918536,
#    0.6848439854148367,
#    0.6767392893309021,
#    0.6750529660035784],
#   'smitrans_esmc': [0.6808617134028163,
#    0.6792770005530827,
#    0.6775635468206525,
#    0.6743379550232951,
#    0.6724751259423649],
#   'molgen_esm2': [0.679540419322169,
#    0.6813198923084736,
#    0.6769969176331703,
#    0.6798513745496841,
#    0.6691535825122592],
#   'molebert_esmc': [0.6887692680625181,
#    0.6859467212808841,
#    0.6897887561684797,
#    0.6774068236229611,
#    0.6803282449231128],
#   'maccskeys_prollama': [0.5966496983018599,
#    0.6049082113464321,
#    0.6037206563782582,
#    0.5977452118865068,
#    0.6018139501666575],
#   'smitrans_esm1b': [0.6752863133460335,
#    0.680522777814092,
#    0.6757242602239638,
#    0.6702398624950092,
#    0.6626679101995179],
#   'ecfp_esm2': [0.674650864659798,
#    0.6865207162863048,
#    0.6840816787145212,
#    0.6706110475445384,
#    0.6682203993969047],
#   'maccskeys_esmc': [0.6571771697386901,
#    0.6532951652111981,
#    0.6572294493796184,
#    0.6444294106359079,
#    0.6467514874415627],
#   'maccskeys_esm2': [0.648939478579998,
#    0.6549681058206938,
#    0.6514454764203331,
#    0.6397870049111287,
#    0.6424754680966525]},
#  'KM': {'molebert_esm1b': [0.6604229598196022,
#    0.6556665509876222,
#    0.6535900434551923,
#    0.6678818816286475,
#    0.6652053526709668],
#   'ecfp_esm1b': [0.6462933004375085,
#    0.6411614157445603,
#    0.6417922690933944,
#    0.6547966840235542,
#    0.6525577375907109],
#   'unimolv2_esm1b': [0.6602941943747049,
#    0.658558238575935,
#    0.6600781098714973,
#    0.6686805855353897,
#    0.673350270005382],
#   'chemberta2_prott5': [0.6534061019827442,
#    0.6552689683661566,
#    0.6543232929703121,
#    0.6584085373904599,
#    0.6677373708169627],
#   'unimolv1_prollama': [0.6183872334071194,
#    0.6240855453547887,
#    0.6283346660396618,
#    0.63021968261016,
#    0.6361032561980196],
#   'rdkitfp_esm2': [0.6330444721540951,
#    0.6286906769763179,
#    0.6279727321734194,
#    0.6315706543825508,
#    0.6374623149100813],
#   'molgen_esm2': [0.6576394131009975,
#    0.6566069189056915,
#    0.653585028435907,
#    0.6606492223118137,
#    0.6636091072244652],
#   'unimolv2_prott5': [0.6603102013544857,
#    0.6600368379222179,
#    0.6630517356536607,
#    0.6676833094347969,
#    0.6762733242836165],
#   'maccskeys_prollama': [0.5886409088879321,
#    0.5897026952590811,
#    0.5939763519791974,
#    0.5990453208698279,
#    0.6059751884513906],
#   'unimolv2_esmc': [0.6518426313412966,
#    0.6502431634954315,
#    0.6549296382533532,
#    0.6640972667049363,
#    0.6657686656669617],
#   'molebert_prollama': [0.6240815788569123,
#    0.6329496868733506,
#    0.6245032043355798,
#    0.638665879724069,
#    0.6427106480176448],
#   'chemberta2_esmc': [0.6500111899697063,
#    0.6481466746227312,
#    0.6477835854224901,
#    0.6545556430985737,
#    0.6570851097833635],
#   'unimolv1_esm2': [0.653093173637036,
#    0.6530660781228841,
#    0.6509111760607211,
#    0.6574057816611741,
#    0.6588355004793024],
#   'ecfp_esmc': [0.6415378695257379,
#    0.634570685541921,
#    0.6299162854455428,
#    0.6495949968101442,
#    0.6485991304297072],
#   'unimolv1_esm1b': [0.6514770527641929,
#    0.6558072637256425,
#    0.6552773504202365,
#    0.6588996341349838,
#    0.6652403391432332],
#   'chemberta2_esm1b': [0.6533266575113394,
#    0.6511822539467789,
#    0.6556821661130312,
#    0.6626813446398364,
#    0.664814059430459],
#   'rdkitfp_esm1b': [0.6360634635700935,
#    0.6360273679471699,
#    0.6334635492147405,
#    0.6381723317162509,
#    0.6445432456203062],
#   'molgen_prott5': [0.6590462724004675,
#    0.6574668202990049,
#    0.658576604367253,
#    0.6638182926532668,
#    0.668787667065343],
#   'maccskeys_prott5': [0.6380113340151232,
#    0.6286203509831594,
#    0.6298900441806576,
#    0.6323608619225219,
#    0.6435948896838943],
#   'rdkitfp_prott5': [0.6344582356222803,
#    0.6374782733668467,
#    0.6369284815331363,
#    0.6349016573370844,
#    0.6426886786318613],
#   'molebert_esmc': [0.656938398656191,
#    0.6505504633374853,
#    0.6472898003743024,
#    0.6603265367714448,
#    0.6583148754652396],
#   'molgen_esm1b': [0.65558135232133,
#    0.6553777490343756,
#    0.656165678616323,
#    0.6635567641841869,
#    0.6686055515718893],
#   'chemberta2_prollama': [0.618140717562448,
#    0.6272550665473303,
#    0.6282006120272372,
#    0.6342913827947311,
#    0.6382304324103188],
#   'smitrans_prott5': [0.6610158707425453,
#    0.6564454625389502,
#    0.6563254574013849,
#    0.6648900051325772,
#    0.6728151368349802],
#   'smitrans_esmc': [0.6536616932488675,
#    0.6497336508069307,
#    0.6540176695273996,
#    0.6599350736225638,
#    0.6659556569791838],
#   'molebert_prott5': [0.6614586569435551,
#    0.659301534014963,
#    0.6561855007575357,
#    0.6638719024805261,
#    0.6693392531119549],
#   'unimolv1_prott5': [0.6573454103876413,
#    0.6535712257850335,
#    0.6561270202586611,
#    0.6572364441190506,
#    0.6661909223042286],
#   'chemberta2_esm2': [0.6535202055351674,
#    0.6509023692743356,
#    0.6543113646338791,
#    0.6568240582700214,
#    0.6616101033876699],
#   'smitrans_esm1b': [0.6595277275794,
#    0.6560929802754634,
#    0.658195150460875,
#    0.6664700405851421,
#    0.6722641967778544],
#   'ecfp_prott5': [0.6509135755623222,
#    0.6438019921696995,
#    0.638176429354842,
#    0.6498000111195729,
#    0.6557739332341466],
#   'unimolv2_esm2': [0.65660394938692,
#    0.6578753250837374,
#    0.6577709012723927,
#    0.6630197933758758,
#    0.6691988815462167],
#   'rdkitfp_prollama': [0.5948020920033451,
#    0.6025753029142554,
#    0.5972589224761529,
#    0.5985959978066644,
#    0.6099126761854743],
#   'ecfp_prollama': [0.6128629776371041,
#    0.6100881585193706,
#    0.6000625123699269,
#    0.6158066320969511,
#    0.6251649657880933],
#   'molgen_prollama': [0.6227452595610297,
#    0.630227458012313,
#    0.6337239756626292,
#    0.6373335763724695,
#    0.6431316408762725],
#   'smitrans_esm2': [0.6592055301765564,
#    0.6537902632338266,
#    0.6526382512504947,
#    0.6597726428889892,
#    0.6657805123626168],
#   'ecfp_esm2': [0.6499548681842269,
#    0.6416197253647803,
#    0.6306088646837267,
#    0.6493007704611018,
#    0.6417887890209111],
#   'molgen_esmc': [0.6514892567488404,
#    0.6508659657149689,
#    0.6533538372899864,
#    0.6587722753695675,
#    0.665505084688095],
#   'unimolv2_prollama': [0.6255733241039245,
#    0.6301880726585964,
#    0.6352225894322261,
#    0.6442688455160415,
#    0.648042033813642],
#   'smitrans_prollama': [0.6256798212127813,
#    0.6298459102115344,
#    0.6347076503590015,
#    0.6428965513636287,
#    0.6480346562740541],
#   'rdkitfp_esmc': [0.6301499686874894,
#    0.6252699656760664,
#    0.6239639697365428,
#    0.6266415215301886,
#    0.6313889038350682],
#   'molebert_esm2': [0.6590915030893132,
#    0.6524418292737952,
#    0.6481292730044228,
#    0.6642282073821146,
#    0.6617504281692992],
#   'unimolv1_esmc': [0.6473757888204028,
#    0.6472513784989763,
#    0.6511109093399936,
#    0.653808858729969,
#    0.6591304108791864],
#   'maccskeys_esm2': [0.6368771870061078,
#    0.6236107609510677,
#    0.6243334961764825,
#    0.6331904274206677,
#    0.638692538120749],
#   'maccskeys_esm1b': [0.6366173597242271,
#    0.6274002447678153,
#    0.6290207234690579,
#    0.635090922017838,
#    0.6437987531670843],
#   'maccskeys_esmc': [0.6307165261311634,
#    0.6177795510068924,
#    0.6209711039902697,
#    0.6280830990196786,
#    0.629350981008264]},
#  'KKM': {'smitrans_prollama': [0.5332363929462416,
#    0.5548938172935789,
#    0.5276822652376058,
#    0.5343733572796234,
#    0.5466040865954336],
#   'ecfp_esm1b': [0.5803805461619296,
#    0.6117988723166533,
#    0.5457072668389313,
#    0.5487683836771686,
#    0.5768056144897914],
#   'ecfp_prott5': [0.5841179366270293,
#    0.6124386636264527,
#    0.5509872909492293,
#    0.551402247234738,
#    0.5875292681716783],
#   'chemberta2_esm2': [0.5852007245229756,
#    0.6028001725357395,
#    0.5608411470035078,
#    0.5679546271611975,
#    0.5772581174551938],
#   'molgen_esmc': [0.5974037071937031,
#    0.6070677019142052,
#    0.574531984041613,
#    0.584471367884857,
#    0.5937611071832753],
#   'rdkitfp_esm1b': [0.5576077681206156,
#    0.5767258665518153,
#    0.5334606811647882,
#    0.5457860994649046,
#    0.5598544224146316],
#   'unimolv2_esm2': [0.5853427201907238,
#    0.6110572485328316,
#    0.5771428880140017,
#    0.5732109044575286,
#    0.5955438995135137],
#   'chemberta2_prott5': [0.5926001974869695,
#    0.6048056507494762,
#    0.5654037593047871,
#    0.5669387435930324,
#    0.58812950078806],
#   'unimolv1_prott5': [0.6000772037183293,
#    0.6208402163876703,
#    0.5772129732963799,
#    0.5777835814059068,
#    0.6035183651616185],
#   'molebert_prott5': [0.6047421658881796,
#    0.6236436338099502,
#    0.5817374712740722,
#    0.5881108096816401,
#    0.6014529548727698],
#   'ecfp_prollama': [0.5293517112309258,
#    0.5627031623609889,
#    0.5111051858229925,
#    0.5047361941803081,
#    0.5365623076241718],
#   'ecfp_esmc': [0.5842890476465082,
#    0.6014178440593081,
#    0.5467620473977102,
#    0.5390963743055776,
#    0.5775306674346062],
#   'molebert_esm2': [0.5947802015066446,
#    0.6228507162341502,
#    0.5805254732897802,
#    0.5780353342565838,
#    0.5929785295486081],
#   'unimolv2_prollama': [0.5403469522518497,
#    0.559538833750715,
#    0.5305961297921303,
#    0.5361801518745298,
#    0.5606201015980248],
#   'rdkitfp_esm2': [0.5481230126636247,
#    0.5705765376656459,
#    0.5367753799016901,
#    0.5432971916114657,
#    0.5591719184185047],
#   'smitrans_esmc': [0.5969874619057249,
#    0.6066750727184267,
#    0.5718129244310534,
#    0.57492951425138,
#    0.5922147087714597],
#   'unimolv1_esmc': [0.5978504297175563,
#    0.6110160699397313,
#    0.5783910634775314,
#    0.583212980996626,
#    0.5986165882946701],
#   'molebert_esmc': [0.5960963534231474,
#    0.6181401513576209,
#    0.5813527176148001,
#    0.5822767373248177,
#    0.6038476065811992],
#   'chemberta2_prollama': [0.5334869028594934,
#    0.5479261737466349,
#    0.5218798587095751,
#    0.522860669429329,
#    0.5339869370427446],
#   'unimolv2_esmc': [0.5860024483549534,
#    0.6082956223715053,
#    0.5740989767449064,
#    0.5785934064100412,
#    0.5954936917567614],
#   'molgen_prott5': [0.599565263932692,
#    0.6174916642964956,
#    0.5738542797428119,
#    0.5857924784621067,
#    0.5925794331441196],
#   'ecfp_esm2': [0.572698578802233,
#    0.6040236181624326,
#    0.5408013556964426,
#    0.5429333513441674,
#    0.5798565180489845],
#   'rdkitfp_prollama': [0.5097417270406893,
#    0.5241574983496807,
#    0.49732681356210096,
#    0.49899011905770596,
#    0.5245938677606135],
#   'maccskeys_esm1b': [0.5508444704993041,
#    0.5812595647942642,
#    0.5414322693718243,
#    0.5378641949566741,
#    0.5662507038063642],
#   'molebert_esm1b': [0.6005929748277685,
#    0.622729903576554,
#    0.5798007689693399,
#    0.5809638559593511,
#    0.5956861799727582],
#   'maccskeys_esmc': [0.5526012381311389,
#    0.5671296209334298,
#    0.536963810318327,
#    0.5366228448463299,
#    0.5665057459018978],
#   'maccskeys_prollama': [0.5001654271970033,
#    0.5258866808764578,
#    0.502505547155105,
#    0.5001386201779496,
#    0.5327399558783923],
#   'unimolv1_esm1b': [0.597914679686909,
#    0.6206041842479613,
#    0.5806155304240936,
#    0.5795188900026127,
#    0.6006555389038746],
#   'rdkitfp_esmc': [0.554435877234857,
#    0.5644907364971314,
#    0.5392077988808762,
#    0.5435206331610669,
#    0.5626553298545779],
#   'maccskeys_prott5': [0.5618894526539651,
#    0.58307277293389,
#    0.5422543652594298,
#    0.5420296856629945,
#    0.5774956332673384],
#   'smitrans_esm1b': [0.5926324170877275,
#    0.6093651605769259,
#    0.5652412810585561,
#    0.5689189879402816,
#    0.5875398890394825],
#   'molgen_prollama': [0.5457274241982629,
#    0.563462575237375,
#    0.5430190719845165,
#    0.5425384119692931,
#    0.5483928981845512],
#   'unimolv1_prollama': [0.5453311306697062,
#    0.5622453778965473,
#    0.5416400513980673,
#    0.5387452559381216,
#    0.5575806676454667],
#   'chemberta2_esmc': [0.5916830018970791,
#    0.5987271625692858,
#    0.5641903053204537,
#    0.5665934472739502,
#    0.5806701847018776],
#   'molgen_esm2': [0.586199303764543,
#    0.6138841594182459,
#    0.5709307347386112,
#    0.5788010319618883,
#    0.5877342315455132],
#   'smitrans_esm2': [0.5874219115113318,
#    0.6065302147237754,
#    0.5686872488330492,
#    0.5718243785199428,
#    0.5931520146809715],
#   'maccskeys_esm2': [0.5464769247113923,
#    0.5774348731791327,
#    0.5304183382204668,
#    0.5276930064784469,
#    0.564847846733114],
#   'unimolv2_prott5': [0.594410724873441,
#    0.6206266016958746,
#    0.5799182138742792,
#    0.5810890522620786,
#    0.6010901865292151],
#   'molebert_prollama': [0.5540608931806263,
#    0.5769287876545881,
#    0.543865359058853,
#    0.5472267381533118,
#    0.5603822176666509],
#   'chemberta2_esm1b': [0.5873835993573437,
#    0.6026631553996167,
#    0.5621604655069944,
#    0.5685809052667414,
#    0.5790639753401414],
#   'molgen_esm1b': [0.5969760691927479,
#    0.617214053794553,
#    0.5771044167054499,
#    0.5837304907402413,
#    0.5934375213973382],
#   'unimolv2_esm1b': [0.5906232172793122,
#    0.6169316542623198,
#    0.5781502155317664,
#    0.5786145439352255,
#    0.5954650962603084],
#   'smitrans_prott5': [0.592396735279433,
#    0.6111964832571416,
#    0.5689084494304553,
#    0.5755353797241127,
#    0.5956242963594436],
#   'unimolv1_esm2': [0.5949017969354282,
#    0.616564489855698,
#    0.5786134485131573,
#    0.5773141863030116,
#    0.5939558440927085],
#   'rdkitfp_prott5': [0.5594347381069423,
#    0.5746141103491396,
#    0.5357432731937002,
#    0.5594330985308535,
#    0.5789237429829386]}}

# %%
# 提取每个类型的DataFrame并重命名列
df_kcat = results['KCAT'][['Model', 'Mean R2', 'Rank']].rename(columns={'Mean R2': 'KCAT_Mean_R2', 'Rank': 'KCAT_Rank'})
df_km = results['KM'][['Model', 'Mean R2', 'Rank']].rename(columns={'Mean R2': 'KM_Mean_R2', 'Rank': 'KM_Rank'})
df_kkm = results['KKM'][['Model', 'Mean R2', 'Rank']].rename(columns={'Mean R2': 'KKM_Mean_R2', 'Rank': 'KKM_Rank'})

# 合并三个DataFrame，确保包含所有模型
merged = df_kcat.merge(df_km, on='Model', how='outer').merge(df_kkm, on='Model', how='outer')

# 计算平均R²和平均Rank
merged['Avg_Mean_R2'] = merged[['KCAT_Mean_R2', 'KM_Mean_R2', 'KKM_Mean_R2']].mean(axis=1)
merged['Avg_Rank'] = merged[['KCAT_Rank', 'KM_Rank', 'KKM_Rank']].mean(axis=1)

# 生成综合排名（按平均Rank升序，平均R²降序）
merged = merged.sort_values(by=['Avg_Rank', 'Avg_Mean_R2'], ascending=[True, False])
merged['Overall_Rank'] = merged['Avg_Rank'].rank(method='min', ascending=True).astype(int)

# 整理列顺序
final_columns = [
    'Model', 
    'KCAT_Mean_R2', 'KM_Mean_R2', 'KKM_Mean_R2', 'Avg_Mean_R2',
    'KCAT_Rank', 'KM_Rank', 'KKM_Rank', 'Avg_Rank', 'Overall_Rank'
]
merged = merged[final_columns]

print("\nOverall Performance Across All Types:")
print(merged.to_string(index=False))

# 保存结果到CSV文件（可选）
merged.to_csv('overall_performance.csv', index=False)
# Out:
# Overall Performance Across All Types:
#               Model  KCAT_Mean_R2  KM_Mean_R2  KKM_Mean_R2  Avg_Mean_R2  KCAT_Rank  KM_Rank  KKM_Rank  Avg_Rank  Overall_Rank
#     unimolv2_prott5      0.686004    0.665471     0.595427     0.648967        2.0      1.0       6.0  3.000000             1
#     molebert_prott5      0.683535    0.662031     0.599937     0.648501        6.0      5.0       1.0  4.000000             2
#      unimolv2_esm1b      0.683986    0.664192     0.591957     0.646712        5.0      2.0      12.0  6.333333             3
#      molebert_esm1b      0.680102    0.660553     0.595955     0.645537       14.0      8.0       3.0  8.333333             4
#       molebert_esmc      0.684448    0.654684     0.596343     0.645158        3.0     21.0       2.0  8.666667             5
#       unimolv2_esmc      0.688272    0.657376     0.588497     0.644715        1.0     15.0      16.0 10.666667             6
#       molgen_prott5      0.678709    0.661539     0.593857     0.644701       19.0      6.0       7.0 10.666667             6
#       unimolv2_esm2      0.682458    0.660894     0.588460     0.643937        9.0      7.0      17.0 11.000000             8
#        molgen_esm1b      0.679793    0.659857     0.593693     0.644448       16.0      9.0      10.0 11.666667             9
#     unimolv1_prott5      0.678258    0.658094     0.595886     0.644080       20.0     12.0       4.0 12.000000            10
#   chemberta2_prott5      0.684179    0.657829     0.583576     0.641861        4.0     13.0      21.0 12.666667            11
#      unimolv1_esm1b      0.678745    0.657340     0.595862     0.643982       18.0     16.0       5.0 13.000000            12
#       molebert_esm2      0.679999    0.657128     0.593834     0.643654       15.0     17.0       8.0 13.333333            13
#         molgen_esmc      0.683021    0.655997     0.591447     0.643488        8.0     19.0      13.0 13.333333            13
#       unimolv1_esmc      0.681507    0.651735     0.593817     0.642353       12.0     23.0       9.0 14.666667            15
#     smitrans_prott5      0.673676    0.662298     0.588732     0.641569       26.0      4.0      14.0 14.666667            15
#    chemberta2_esm1b      0.682409    0.657537     0.579970     0.639972       10.0     14.0      23.0 15.666667            17
#         molgen_esm2      0.677372    0.658418     0.587510     0.641100       21.0     10.0      18.0 16.333333            18
#      smitrans_esm1b      0.672888    0.662510     0.584740     0.640046       27.0      3.0      20.0 16.666667            19
#     chemberta2_esmc      0.683284    0.651516     0.580373     0.638391        7.0     24.0      22.0 17.666667            20
#       smitrans_esmc      0.676903    0.656661     0.588524     0.640696       22.0     18.0      15.0 18.333333            21
#       unimolv1_esm2      0.676692    0.654662     0.592270     0.641208       25.0     22.0      11.0 19.333333            22
#       smitrans_esm2      0.672053    0.658237     0.585523     0.638605       28.0     11.0      19.0 19.333333            22
#     chemberta2_esm2      0.679408    0.655434     0.578811     0.637884       17.0     20.0      24.0 20.333333            24
#         ecfp_prott5      0.682327    0.647693     0.577295     0.635772       11.0     25.0      25.0 20.333333            24
#           ecfp_esmc      0.680119    0.640844     0.569819     0.630261       13.0     28.0      27.0 22.666667            26
#          ecfp_esm1b      0.676823    0.647320     0.572692     0.632279       23.0     26.0      26.0 25.000000            27
#           ecfp_esm2      0.676817    0.642655     0.568063     0.629178       24.0     27.0      28.0 26.333333            28
#      rdkitfp_prott5      0.658927    0.637291     0.561630     0.619283       30.0     30.0      29.0 29.666667            29
#       rdkitfp_esm1b      0.657762    0.637654     0.554687     0.616701       31.0     29.0      33.0 31.000000            30
#    maccskeys_prott5      0.651925    0.634495     0.561348     0.615923       33.0     33.0      30.0 32.000000            31
#     maccskeys_esm1b      0.649333    0.634386     0.555530     0.613083       35.0     34.0      32.0 33.666667            32
#        rdkitfp_esmc      0.662942    0.627483     0.552862     0.614429       29.0     40.0      34.0 34.333333            33
#   molebert_prollama      0.641246    0.632582     0.556493     0.610107       37.0     36.0      31.0 34.666667            34
#        rdkitfp_esm2      0.657510    0.631748     0.551589     0.613616       32.0     37.0      36.0 35.000000            35
#   unimolv2_prollama      0.632739    0.636659     0.545456     0.604952       38.0     31.0      40.0 36.333333            36
#      maccskeys_esmc      0.651777    0.625380     0.551965     0.609707       34.0     42.0      35.0 37.000000            37
#      maccskeys_esm2      0.647523    0.631341     0.549374     0.609413       36.0     38.0      37.0 37.000000            37
#     molgen_prollama      0.621488    0.633432     0.548628     0.601183       42.0     35.0      39.0 38.666667            39
#   smitrans_prollama      0.618304    0.636233     0.539358     0.597965       43.0     32.0      41.0 38.666667            39
#   unimolv1_prollama      0.626332    0.627426     0.549108     0.600955       41.0     41.0      38.0 40.000000            41
# chemberta2_prollama      0.631830    0.629224     0.532028     0.597694       39.0     39.0      42.0 40.000000            41
#       ecfp_prollama      0.631646    0.612797     0.528892     0.591111       40.0     43.0      43.0 42.000000            43
#    rdkitfp_prollama      0.609909    0.600629     0.510962     0.573833       44.0     44.0      45.0 44.333333            44
#  maccskeys_prollama      0.600968    0.595468     0.512287     0.569574       45.0     45.0      44.0 44.666667            45

# %%
# 提取每个类型的DataFrame并重命名列
df_kcat = results['KCAT'][['Model', 'Mean R2', 'Rank']].rename(columns={'Mean R2': 'KCAT_Mean_R2', 'Rank': 'KCAT_Rank'})
df_km = results['KM'][['Model', 'Mean R2', 'Rank']].rename(columns={'Mean R2': 'KM_Mean_R2', 'Rank': 'KM_Rank'})
df_kkm = results['KKM'][['Model', 'Mean R2', 'Rank']].rename(columns={'Mean R2': 'KKM_Mean_R2', 'Rank': 'KKM_Rank'})

# 合并三个DataFrame，确保包含所有模型
merged = df_kcat.merge(df_km, on='Model', how='outer').merge(df_kkm, on='Model', how='outer')

# 计算平均R²和平均Rank
merged['Avg_Mean_R2'] = merged[['KCAT_Mean_R2', 'KM_Mean_R2', 'KKM_Mean_R2']].mean(axis=1)
merged['Avg_Rank'] = merged[['KCAT_Rank', 'KM_Rank', 'KKM_Rank']].mean(axis=1)

# 对 R² 值保留三位小数
merged['KCAT_Mean_R2'] = merged['KCAT_Mean_R2'].round(3)
merged['KM_Mean_R2'] = merged['KM_Mean_R2'].round(3)
merged['KKM_Mean_R2'] = merged['KKM_Mean_R2'].round(3)
merged['Avg_Mean_R2'] = merged['Avg_Mean_R2'].round(3)

# 生成综合排名（按平均Rank升序，平均R²降序）
merged = merged.sort_values(by=['Avg_Rank', 'Avg_Mean_R2'], ascending=[True, False])

# merged['Overall_Rank'] = merged['Avg_Rank'].rank(method='min', ascending=True).astype(int)
################################## 可选 ###################################
merged['Overall_Rank'] = merged['Avg_Mean_R2'].rank(method='min', ascending=False).astype(int)

# 整理列顺序
final_columns = [
    'Model', 
    'KCAT_Mean_R2', 'KM_Mean_R2', 'KKM_Mean_R2', 'Avg_Mean_R2',
    'KCAT_Rank', 'KM_Rank', 'KKM_Rank', 'Avg_Rank', 'Overall_Rank'
]
merged = merged[final_columns]

print("\nOverall Performance Across All Types:")
print(merged.to_string(index=False))

# 保存结果到CSV文件（可选）
merged.to_csv('overall_performance.csv', index=False)
# Out:
# Overall Performance Across All Types:
#               Model  KCAT_Mean_R2  KM_Mean_R2  KKM_Mean_R2  Avg_Mean_R2  KCAT_Rank  KM_Rank  KKM_Rank  Avg_Rank  Overall_Rank
#     unimolv2_prott5         0.686       0.665        0.595        0.649        2.0      1.0       6.0  3.000000             1
#     molebert_prott5         0.684       0.662        0.600        0.649        6.0      5.0       1.0  4.000000             1
#      unimolv2_esm1b         0.684       0.664        0.592        0.647        5.0      2.0      12.0  6.333333             3
#      molebert_esm1b         0.680       0.661        0.596        0.646       14.0      8.0       3.0  8.333333             4
#       molebert_esmc         0.684       0.655        0.596        0.645        3.0     21.0       2.0  8.666667             5
#       molgen_prott5         0.679       0.662        0.594        0.645       19.0      6.0       7.0 10.666667             5
#       unimolv2_esmc         0.688       0.657        0.588        0.645        1.0     15.0      16.0 10.666667             5
#       unimolv2_esm2         0.682       0.661        0.588        0.644        9.0      7.0      17.0 11.000000             8
#        molgen_esm1b         0.680       0.660        0.594        0.644       16.0      9.0      10.0 11.666667             8
#     unimolv1_prott5         0.678       0.658        0.596        0.644       20.0     12.0       4.0 12.000000             8
#   chemberta2_prott5         0.684       0.658        0.584        0.642        4.0     13.0      21.0 12.666667            14
#      unimolv1_esm1b         0.679       0.657        0.596        0.644       18.0     16.0       5.0 13.000000             8
#       molebert_esm2         0.680       0.657        0.594        0.644       15.0     17.0       8.0 13.333333             8
#         molgen_esmc         0.683       0.656        0.591        0.643        8.0     19.0      13.0 13.333333            13
#     smitrans_prott5         0.674       0.662        0.589        0.642       26.0      4.0      14.0 14.666667            14
#       unimolv1_esmc         0.682       0.652        0.594        0.642       12.0     23.0       9.0 14.666667            14
#    chemberta2_esm1b         0.682       0.658        0.580        0.640       10.0     14.0      23.0 15.666667            20
#         molgen_esm2         0.677       0.658        0.588        0.641       21.0     10.0      18.0 16.333333            17
#      smitrans_esm1b         0.673       0.663        0.585        0.640       27.0      3.0      20.0 16.666667            20
#     chemberta2_esmc         0.683       0.652        0.580        0.638        7.0     24.0      22.0 17.666667            23
#       smitrans_esmc         0.677       0.657        0.589        0.641       22.0     18.0      15.0 18.333333            17
#       unimolv1_esm2         0.677       0.655        0.592        0.641       25.0     22.0      11.0 19.333333            17
#       smitrans_esm2         0.672       0.658        0.586        0.639       28.0     11.0      19.0 19.333333            22
#     chemberta2_esm2         0.679       0.655        0.579        0.638       17.0     20.0      24.0 20.333333            23
#         ecfp_prott5         0.682       0.648        0.577        0.636       11.0     25.0      25.0 20.333333            25
#           ecfp_esmc         0.680       0.641        0.570        0.630       13.0     28.0      27.0 22.666667            27
#          ecfp_esm1b         0.677       0.647        0.573        0.632       23.0     26.0      26.0 25.000000            26
#           ecfp_esm2         0.677       0.643        0.568        0.629       24.0     27.0      28.0 26.333333            28
#      rdkitfp_prott5         0.659       0.637        0.562        0.619       30.0     30.0      29.0 29.666667            29
#       rdkitfp_esm1b         0.658       0.638        0.555        0.617       31.0     29.0      33.0 31.000000            30
#    maccskeys_prott5         0.652       0.634        0.561        0.616       33.0     33.0      30.0 32.000000            31
#     maccskeys_esm1b         0.649       0.634        0.556        0.613       35.0     34.0      32.0 33.666667            34
#        rdkitfp_esmc         0.663       0.627        0.553        0.614       29.0     40.0      34.0 34.333333            32
#   molebert_prollama         0.641       0.633        0.556        0.610       37.0     36.0      31.0 34.666667            35
#        rdkitfp_esm2         0.658       0.632        0.552        0.614       32.0     37.0      36.0 35.000000            32
#   unimolv2_prollama         0.633       0.637        0.545        0.605       38.0     31.0      40.0 36.333333            38
#      maccskeys_esmc         0.652       0.625        0.552        0.610       34.0     42.0      35.0 37.000000            35
#      maccskeys_esm2         0.648       0.631        0.549        0.609       36.0     38.0      37.0 37.000000            37
#     molgen_prollama         0.621       0.633        0.549        0.601       42.0     35.0      39.0 38.666667            39
#   smitrans_prollama         0.618       0.636        0.539        0.598       43.0     32.0      41.0 38.666667            41
#   unimolv1_prollama         0.626       0.627        0.549        0.601       41.0     41.0      38.0 40.000000            39
# chemberta2_prollama         0.632       0.629        0.532        0.598       39.0     39.0      42.0 40.000000            41
#       ecfp_prollama         0.632       0.613        0.529        0.591       40.0     43.0      43.0 42.000000            43
#    rdkitfp_prollama         0.610       0.601        0.511        0.574       44.0     44.0      45.0 44.333333            44
#  maccskeys_prollama         0.601       0.595        0.512        0.570       45.0     45.0      44.0 44.666667            45

# %%
import pandas as pd
import re

# 定义文件路径
file_paths = {
    'KCAT': {
        'cv0': 'all_bianyifangxiang_KCAT_cv0.txt',
        'cv1': 'all_bianyifangxiang_KCAT_cv1.txt',
        'cv2': 'all_bianyifangxiang_KCAT_cv2.txt',
        'cv3': 'all_bianyifangxiang_KCAT_cv3.txt',
        'cv4': 'all_bianyifangxiang_KCAT_cv4.txt'
    },
    'KM': {
        'cv0': 'all_bianyifangxiang_KM_cv0.txt',
        'cv1': 'all_bianyifangxiang_KM_cv1.txt',
        'cv2': 'all_bianyifangxiang_KM_cv2.txt',
        'cv3': 'all_bianyifangxiang_KM_cv3.txt',
        'cv4': 'all_bianyifangxiang_KM_cv4.txt'
    },
    'KKM': {
        'cv0': 'all_bianyifangxiang_KKM_cv0.txt',
        'cv1': 'all_bianyifangxiang_KKM_cv1.txt',
        'cv2': 'all_bianyifangxiang_KKM_cv2.txt',
        'cv3': 'all_bianyifangxiang_KKM_cv3.txt',
        'cv4': 'all_bianyifangxiang_KKM_cv4.txt'
    }
}

def process_file(file_path):
    """
    处理单个文件，提取模型名称和指标值（Accuracy, Precision, Recall, F1）。
    """
    with open(file_path, 'r') as file:
        content = file.read()

    # 正则表达式匹配模型名称和指标值
    pattern = re.compile(r'(\w+): Accuracy: ([\d.]+) Precision: ([\d.]+) Recall: ([\d.]+) F1: ([\d.]+)')
    matches = pattern.findall(content)

    # 提取数据
    data = []
    for match in matches:
        model = match[0]
        accuracy = float(match[1])
        precision = float(match[2])
        recall = float(match[3])
        f1 = float(match[4])
        data.append((model, accuracy, precision, recall, f1))

    # 创建DataFrame
    df = pd.DataFrame(data, columns=['Model', 'Accuracy', 'Precision', 'Recall', 'F1'])
    return df

# 初始化存储每个类型的指标值的字典
type_metrics_data = {
    'KCAT': {},
    'KM': {},
    'KKM': {}
}

# 处理每个文件
for file_type, cv_files in file_paths.items():
    for cv, file_path in cv_files.items():
        # 处理文件
        df = process_file(file_path)
        # 将结果存储到 type_metrics_data 中
        for _, row in df.iterrows():
            model = row['Model']
            metrics = row[['Accuracy', 'Precision', 'Recall', 'F1']].tolist()
            if model not in type_metrics_data[file_type]:
                type_metrics_data[file_type][model] = []
            type_metrics_data[file_type][model].append(metrics)

# 计算每个类型的指标均值并排序
results = {}
for file_type, models_metrics in type_metrics_data.items():
    # 计算每个模型的指标均值
    mean_metrics = {}
    for model, metrics_list in models_metrics.items():
        # 计算每个指标的均值
        mean_accuracy = sum([m[0] for m in metrics_list]) / len(metrics_list)
        mean_precision = sum([m[1] for m in metrics_list]) / len(metrics_list)
        mean_recall = sum([m[2] for m in metrics_list]) / len(metrics_list)
        mean_f1 = sum([m[3] for m in metrics_list]) / len(metrics_list)
        mean_metrics[model] = [mean_accuracy, mean_precision, mean_recall, mean_f1]

    # 创建 DataFrame
    df_mean_metrics = pd.DataFrame(list(mean_metrics.items()), columns=['Model', 'Mean Metrics'])
    # 展开 Mean Metrics 列
    df_mean_metrics[['Mean Accuracy', 'Mean Precision', 'Mean Recall', 'Mean F1']] = pd.DataFrame(df_mean_metrics['Mean Metrics'].tolist(), index=df_mean_metrics.index)
    df_mean_metrics = df_mean_metrics.drop(columns=['Mean Metrics'])

    # 按 Mean Accuracy 排序并计算排名
    df_mean_metrics = df_mean_metrics.sort_values(by='Mean Accuracy', ascending=False)
    df_mean_metrics['Rank'] = df_mean_metrics['Mean Accuracy'].rank(ascending=False, method='min')

    # 存储结果
    results[file_type] = df_mean_metrics

# 打印结果
for file_type, df in results.items():
    print(f"Results for {file_type}:")
    print(df)
    print("\n")

# 保存结果到 CSV 文件（可选）
# for file_type, df in results.items():
#     df.to_csv(f'mean_metrics_rank_{file_type}.csv', index=False)
df
# Out:
# Results for KCAT:
#                        Model  Mean Accuracy  Mean Precision  Mean Recall  \
# 13      molebert_prott5_KCAT       0.883779        0.754972     0.670750
# 33          ecfp_prott5_KCAT       0.883191        0.747540     0.679613
# 11        molebert_esm2_KCAT       0.882700        0.752396     0.667477
# 31            ecfp_esm2_KCAT       0.880938        0.745874     0.666140
# 38       rdkitfp_prott5_KCAT       0.880913        0.739608     0.677121
# 10       molebert_esm1b_KCAT       0.880907        0.752252     0.654728
# 12        molebert_esmc_KCAT       0.880729        0.746701     0.663293
# 36         rdkitfp_esm2_KCAT       0.880034        0.743916     0.663226
# 35        rdkitfp_esm1b_KCAT       0.879620        0.741898     0.663553
# 30           ecfp_esm1b_KCAT       0.878945        0.740912     0.661770
# 32            ecfp_esmc_KCAT       0.878855        0.740492     0.660987
# 43     maccskeys_prott5_KCAT       0.877667        0.731330     0.670268
# 37         rdkitfp_esmc_KCAT       0.876860        0.732845     0.660790
# 23      unimolv2_prott5_KCAT       0.876372        0.735767     0.651120
# 40      maccskeys_esm1b_KCAT       0.876366        0.730885     0.660878
# 18      unimolv1_prott5_KCAT       0.875771        0.738068     0.642161
# 22        unimolv2_esmc_KCAT       0.875588        0.735741     0.645377
# 41       maccskeys_esm2_KCAT       0.874695        0.725577     0.659007
# 20       unimolv2_esm1b_KCAT       0.874592        0.734383     0.640847
# 28    chemberta2_prott5_KCAT       0.873993        0.732082     0.640885
# 21        unimolv2_esm2_KCAT       0.873983        0.733492     0.637928
# 17        unimolv1_esmc_KCAT       0.873795        0.735613     0.632292
# 8         molgen_prott5_KCAT       0.873613        0.733934     0.634503
# 14    molebert_prollama_KCAT       0.873492        0.724629     0.652055
# 5          molgen_esm1b_KCAT       0.873312        0.732273     0.635775
# 15       unimolv1_esm1b_KCAT       0.873300        0.735017     0.630463
# 6           molgen_esm2_KCAT       0.872826        0.726669     0.642363
# 27      chemberta2_esmc_KCAT       0.872805        0.730202     0.635752
# 16        unimolv1_esm2_KCAT       0.872502        0.729413     0.634759
# 42       maccskeys_esmc_KCAT       0.872325        0.716195     0.659964
# 7           molgen_esmc_KCAT       0.872138        0.729273     0.632074
# 34        ecfp_prollama_KCAT       0.871820        0.717005     0.654229
# 1         smitrans_esm2_KCAT       0.871236        0.729793     0.624033
# 25     chemberta2_esm1b_KCAT       0.870520        0.725392     0.627754
# 26      chemberta2_esm2_KCAT       0.870160        0.724613     0.625464
# 3       smitrans_prott5_KCAT       0.870135        0.726014     0.623621
# 0        smitrans_esm1b_KCAT       0.869633        0.722654     0.626333
# 2         smitrans_esmc_KCAT       0.867780        0.716395     0.623524
# 39     rdkitfp_prollama_KCAT       0.867358        0.703352     0.648287
# 44   maccskeys_prollama_KCAT       0.865080        0.695967     0.646855
# 24    unimolv2_prollama_KCAT       0.863392        0.703987     0.615621
# 19    unimolv1_prollama_KCAT       0.862316        0.702504     0.610003
# 9       molgen_prollama_KCAT       0.860334        0.695969     0.607233
# 29  chemberta2_prollama_KCAT       0.859954        0.697522     0.600264
# 4     smitrans_prollama_KCAT       0.857261        0.688308     0.598192
#
#      Mean F1  Rank
# 13  0.709756   1.0
# 33  0.711522   2.0
# 11  0.706849   3.0
# 31  0.703339   4.0
# 38  0.706774   5.0
# 10  0.699677   6.0
# 12  0.702073   7.0
# 36  0.700906   8.0
# 35  0.700321   9.0
# 30  0.698630  10.0
# 32  0.698018  11.0
# 43  0.698978  12.0
# 37  0.694610  13.0
# 23  0.690597  14.0
# 40  0.693885  15.0
# 18  0.686562  16.0
# 22  0.687308  17.0
# 41  0.690381  18.0
# 20  0.684114  19.0
# 28  0.683116  20.0
# 21  0.682121  21.0
# 17  0.679862  22.0
# 8   0.680047  23.0
# 14  0.686003  24.0
# 5   0.680118  25.0
# 15  0.678448  26.0
# 6   0.681550  27.0
# 27  0.679280  28.0
# 16  0.678480  29.0
# 42  0.686580  30.0
# 7   0.676770  31.0
# 34  0.683890  32.0
# 1   0.672445  33.0
# 25  0.672673  34.0
# 26  0.671195  35.0
# 3   0.670487  36.0
# 0   0.670591  37.0
# 2   0.666477  38.0
# 39  0.674391  39.0
# 44  0.670245  40.0
# 24  0.656367  41.0
# 19  0.652423  42.0
# 9   0.648215  43.0
# 29  0.644826  44.0
# 4   0.639829  45.0
#
#
# Results for KM:
#                      Model  Mean Accuracy  Mean Precision  Mean Recall  \
# 22        unimolv2_esmc_KM       0.766974        0.808128     0.838283
# 8         molgen_prott5_KM       0.765770        0.810124     0.832625
# 3       smitrans_prott5_KM       0.764528        0.806708     0.835793
# 23      unimolv2_prott5_KM       0.763857        0.808796     0.830921
# 5          molgen_esm1b_KM       0.762793        0.806332     0.832731
# 17        unimolv1_esmc_KM       0.762640        0.805570     0.833967
# 28    chemberta2_prott5_KM       0.762567        0.808356     0.828967
# 27      chemberta2_esmc_KM       0.761777        0.807384     0.829020
# 7           molgen_esmc_KM       0.761461        0.806505     0.829724
# 16        unimolv1_esm2_KM       0.761132        0.805925     0.830352
# 2         smitrans_esmc_KM       0.760382        0.804854     0.830285
# 20       unimolv2_esm1b_KM       0.759734        0.803021     0.832110
# 18      unimolv1_prott5_KM       0.759404        0.805248     0.827836
# 6           molgen_esm2_KM       0.758356        0.802802     0.829766
# 13      molebert_prott5_KM       0.758169        0.803448     0.828078
# 21        unimolv2_esm2_KM       0.757222        0.803628     0.826168
# 25     chemberta2_esm1b_KM       0.756977        0.802401     0.827592
# 1         smitrans_esm2_KM       0.756016        0.799747     0.830421
# 0        smitrans_esm1b_KM       0.755767        0.801237     0.827001
# 11        molebert_esm2_KM       0.755329        0.798766     0.830689
# 15       unimolv1_esm1b_KM       0.755196        0.799813     0.828421
# 26      chemberta2_esm2_KM       0.754709        0.802319     0.823281
# 33          ecfp_prott5_KM       0.754167        0.799888     0.826203
# 24    unimolv2_prollama_KM       0.753920        0.799843     0.825655
# 38       rdkitfp_prott5_KM       0.753776        0.799696     0.825529
# 10       molebert_esm1b_KM       0.753691        0.798091     0.828385
# 9       molgen_prollama_KM       0.752420        0.797250     0.826855
# 19    unimolv1_prollama_KM       0.751660        0.796244     0.827322
# 4     smitrans_prollama_KM       0.751649        0.797674     0.824668
# 43     maccskeys_prott5_KM       0.751102        0.797520     0.824079
# 12        molebert_esmc_KM       0.750880        0.795049     0.827867
# 40      maccskeys_esm1b_KM       0.749974        0.794704     0.826916
# 30           ecfp_esm1b_KM       0.749568        0.793468     0.828164
# 31            ecfp_esm2_KM       0.747551        0.793170     0.824370
# 37         rdkitfp_esmc_KM       0.747442        0.794554     0.821488
# 41       maccskeys_esm2_KM       0.746758        0.793555     0.822324
# 29  chemberta2_prollama_KM       0.746687        0.794855     0.819310
# 35        rdkitfp_esm1b_KM       0.746663        0.795123     0.818640
# 32            ecfp_esmc_KM       0.746294        0.793049     0.822249
# 42       maccskeys_esmc_KM       0.746147        0.794959     0.818368
# 14    molebert_prollama_KM       0.745476        0.793265     0.819706
# 34        ecfp_prollama_KM       0.743197        0.789424     0.821644
# 36         rdkitfp_esm2_KM       0.738902        0.790570     0.810531
# 44   maccskeys_prollama_KM       0.738825        0.788052     0.814923
# 39     rdkitfp_prollama_KM       0.737006        0.789517     0.808731
#
#      Mean F1  Rank
# 22  0.822893   1.0
# 8   0.821193   2.0
# 3   0.820941   3.0
# 23  0.819626   4.0
# 5   0.819301   5.0
# 17  0.819450   6.0
# 28  0.818469   7.0
# 27  0.818034   8.0
# 7   0.817899   9.0
# 16  0.817822  10.0
# 2   0.817323  11.0
# 20  0.817265  12.0
# 18  0.816321  13.0
# 6   0.816010  14.0
# 13  0.815535  15.0
# 21  0.814679  16.0
# 25  0.814758  17.0
# 1   0.814724  18.0
# 0   0.813875  19.0
# 11  0.814342  20.0
# 15  0.813808  21.0
# 26  0.812600  22.0
# 33  0.812736  23.0
# 24  0.812519  24.0
# 38  0.812294  25.0
# 10  0.812903  26.0
# 9   0.811757  27.0
# 19  0.811399  28.0
# 4   0.810913  29.0
# 43  0.810463  30.0
# 12  0.811035  31.0
# 40  0.810336  32.0
# 30  0.810300  33.0
# 31  0.808347  34.0
# 37  0.807678  35.0
# 41  0.807469  36.0
# 29  0.806881  37.0
# 35  0.806649  38.0
# 32  0.807179  39.0
# 42  0.806312  40.0
# 14  0.806208  41.0
# 34  0.805162  42.0
# 36  0.800333  43.0
# 44  0.801161  44.0
# 39  0.798886  45.0
#
#
# Results for KKM:
#                       Model  Mean Accuracy  Mean Precision  Mean Recall  \
# 18      unimolv1_prott5_KKM       0.859771        0.739102     0.700065
# 8         molgen_prott5_KKM       0.857469        0.728624     0.705804
# 25     chemberta2_esm1b_KKM       0.856827        0.727335     0.709128
# 26      chemberta2_esm2_KKM       0.856705        0.726506     0.707033
# 15       unimolv1_esm1b_KKM       0.856227        0.725257     0.707241
# 3       smitrans_prott5_KKM       0.854665        0.723514     0.701292
# 2         smitrans_esmc_KKM       0.854631        0.729042     0.689474
# 5          molgen_esm1b_KKM       0.854497        0.726771     0.692703
# 28    chemberta2_prott5_KKM       0.854400        0.723468     0.699090
# 23      unimolv2_prott5_KKM       0.854121        0.724015     0.697277
# 11        molebert_esm2_KKM       0.853846        0.728093     0.685645
# 21        unimolv2_esm2_KKM       0.853793        0.720701     0.701079
# 6           molgen_esm2_KKM       0.853544        0.722318     0.695261
# 1         smitrans_esm2_KKM       0.853254        0.719966     0.700292
# 16        unimolv1_esm2_KKM       0.853231        0.720373     0.697929
# 17        unimolv1_esmc_KKM       0.852617        0.723501     0.687982
# 0        smitrans_esm1b_KKM       0.852470        0.720474     0.694104
# 7           molgen_esmc_KKM       0.852204        0.717146     0.699948
# 10       molebert_esm1b_KKM       0.852202        0.727558     0.678472
# 13      molebert_prott5_KKM       0.851627        0.721227     0.687326
# 27      chemberta2_esmc_KKM       0.851097        0.716303     0.693568
# 12        molebert_esmc_KKM       0.850454        0.722165     0.677175
# 36         rdkitfp_esm2_KKM       0.849080        0.716544     0.681489
# 38       rdkitfp_prott5_KKM       0.849005        0.717174     0.679140
# 35        rdkitfp_esm1b_KKM       0.848532        0.713196     0.685126
# 20       unimolv2_esm1b_KKM       0.848352        0.712941     0.684467
# 22        unimolv2_esmc_KKM       0.848256        0.713020     0.684153
# 19    unimolv1_prollama_KKM       0.847002        0.706328     0.690119
# 37         rdkitfp_esmc_KKM       0.845164        0.713177     0.664268
# 9       molgen_prollama_KKM       0.844776        0.699071     0.694354
# 30           ecfp_esm1b_KKM       0.844253        0.710036     0.664749
# 43     maccskeys_prott5_KKM       0.842952        0.700437     0.676358
# 24    unimolv2_prollama_KKM       0.842767        0.694052     0.691531
# 41       maccskeys_esm2_KKM       0.842505        0.699982     0.674453
# 40      maccskeys_esm1b_KKM       0.842253        0.699076     0.676333
# 4     smitrans_prollama_KKM       0.841199        0.691622     0.687630
# 14    molebert_prollama_KKM       0.841042        0.697931     0.670350
# 33          ecfp_prott5_KKM       0.840887        0.698125     0.668822
# 29  chemberta2_prollama_KKM       0.840609        0.692462     0.681310
# 32            ecfp_esmc_KKM       0.839528        0.701486     0.653250
# 42       maccskeys_esmc_KKM       0.839455        0.696520     0.663785
# 31            ecfp_esm2_KKM       0.838886        0.695155     0.661976
# 39     rdkitfp_prollama_KKM       0.834081        0.681384     0.664123
# 44   maccskeys_prollama_KKM       0.830326        0.674178     0.657659
# 34        ecfp_prollama_KKM       0.829725        0.675006     0.647538
#
#      Mean F1  Rank
# 18  0.718981   1.0
# 8   0.716891   2.0
# 25  0.717960   3.0
# 26  0.716437   4.0
# 15  0.715959   5.0
# 3   0.712152   6.0
# 2   0.708280   7.0
# 5   0.709212   8.0
# 28  0.710759   9.0
# 23  0.710153  10.0
# 11  0.706180  11.0
# 21  0.710626  12.0
# 6   0.708369  13.0
# 1   0.709821  14.0
# 16  0.708748  15.0
# 17  0.705085  16.0
# 0   0.706848  17.0
# 7   0.708228  18.0
# 10  0.701980  19.0
# 13  0.703774  20.0
# 27  0.704662  21.0
# 12  0.698739  22.0
# 36  0.698499  23.0
# 38  0.697494  24.0
# 35  0.698794  25.0
# 20  0.698223  26.0
# 22  0.698149  27.0
# 19  0.697871  28.0
# 37  0.687745  29.0
# 9   0.695934  30.0
# 30  0.686376  31.0
# 43  0.687999  32.0
# 24  0.692494  33.0
# 41  0.686757  34.0
# 40  0.687296  35.0
# 4   0.689329  36.0
# 14  0.683537  37.0
# 33  0.682861  38.0
# 29  0.686370  39.0
# 32  0.676001  40.0
# 42  0.679606  41.0
# 31  0.677934  42.0
# 39  0.672289  43.0
# 44  0.664957  44.0
# 34  0.660654  45.0
#                       Model  Mean Accuracy  Mean Precision  Mean Recall  \
# 18      unimolv1_prott5_KKM       0.859771        0.739102     0.700065
# 8         molgen_prott5_KKM       0.857469        0.728624     0.705804
# 25     chemberta2_esm1b_KKM       0.856827        0.727335     0.709128
# 26      chemberta2_esm2_KKM       0.856705        0.726506     0.707033
# 15       unimolv1_esm1b_KKM       0.856227        0.725257     0.707241
# 3       smitrans_prott5_KKM       0.854665        0.723514     0.701292
# 2         smitrans_esmc_KKM       0.854631        0.729042     0.689474
# 5          molgen_esm1b_KKM       0.854497        0.726771     0.692703
# 28    chemberta2_prott5_KKM       0.854400        0.723468     0.699090
# 23      unimolv2_prott5_KKM       0.854121        0.724015     0.697277
# 11        molebert_esm2_KKM       0.853846        0.728093     0.685645
# 21        unimolv2_esm2_KKM       0.853793        0.720701     0.701079
# 6           molgen_esm2_KKM       0.853544        0.722318     0.695261
# 1         smitrans_esm2_KKM       0.853254        0.719966     0.700292
# 16        unimolv1_esm2_KKM       0.853231        0.720373     0.697929
# 17        unimolv1_esmc_KKM       0.852617        0.723501     0.687982
# 0        smitrans_esm1b_KKM       0.852470        0.720474     0.694104
# 7           molgen_esmc_KKM       0.852204        0.717146     0.699948
# 10       molebert_esm1b_KKM       0.852202        0.727558     0.678472
# 13      molebert_prott5_KKM       0.851627        0.721227     0.687326
# 27      chemberta2_esmc_KKM       0.851097        0.716303     0.693568
# 12        molebert_esmc_KKM       0.850454        0.722165     0.677175
# 36         rdkitfp_esm2_KKM       0.849080        0.716544     0.681489
# 38       rdkitfp_prott5_KKM       0.849005        0.717174     0.679140
# 35        rdkitfp_esm1b_KKM       0.848532        0.713196     0.685126
# 20       unimolv2_esm1b_KKM       0.848352        0.712941     0.684467
# 22        unimolv2_esmc_KKM       0.848256        0.713020     0.684153
# 19    unimolv1_prollama_KKM       0.847002        0.706328     0.690119
# 37         rdkitfp_esmc_KKM       0.845164        0.713177     0.664268
# 9       molgen_prollama_KKM       0.844776        0.699071     0.694354
# 30           ecfp_esm1b_KKM       0.844253        0.710036     0.664749
# 43     maccskeys_prott5_KKM       0.842952        0.700437     0.676358
# 24    unimolv2_prollama_KKM       0.842767        0.694052     0.691531
# 41       maccskeys_esm2_KKM       0.842505        0.699982     0.674453
# 40      maccskeys_esm1b_KKM       0.842253        0.699076     0.676333
# 4     smitrans_prollama_KKM       0.841199        0.691622     0.687630
# 14    molebert_prollama_KKM       0.841042        0.697931     0.670350
# 33          ecfp_prott5_KKM       0.840887        0.698125     0.668822
# 29  chemberta2_prollama_KKM       0.840609        0.692462     0.681310
# 32            ecfp_esmc_KKM       0.839528        0.701486     0.653250
# 42       maccskeys_esmc_KKM       0.839455        0.696520     0.663785
# 31            ecfp_esm2_KKM       0.838886        0.695155     0.661976
# 39     rdkitfp_prollama_KKM       0.834081        0.681384     0.664123
# 44   maccskeys_prollama_KKM       0.830326        0.674178     0.657659
# 34        ecfp_prollama_KKM       0.829725        0.675006     0.647538
#
#      Mean F1  Rank
# 18  0.718981   1.0
# 8   0.716891   2.0
# 25  0.717960   3.0
# 26  0.716437   4.0
# 15  0.715959   5.0
# 3   0.712152   6.0
# 2   0.708280   7.0
# 5   0.709212   8.0
# 28  0.710759   9.0
# 23  0.710153  10.0
# 11  0.706180  11.0
# 21  0.710626  12.0
# 6   0.708369  13.0
# 1   0.709821  14.0
# 16  0.708748  15.0
# 17  0.705085  16.0
# 0   0.706848  17.0
# 7   0.708228  18.0
# 10  0.701980  19.0
# 13  0.703774  20.0
# 27  0.704662  21.0
# 12  0.698739  22.0
# 36  0.698499  23.0
# 38  0.697494  24.0
# 35  0.698794  25.0
# 20  0.698223  26.0
# 22  0.698149  27.0
# 19  0.697871  28.0
# 37  0.687745  29.0
# 9   0.695934  30.0
# 30  0.686376  31.0
# 43  0.687999  32.0
# 24  0.692494  33.0
# 41  0.686757  34.0
# 40  0.687296  35.0
# 4   0.689329  36.0
# 14  0.683537  37.0
# 33  0.682861  38.0
# 29  0.686370  39.0
# 32  0.676001  40.0
# 42  0.679606  41.0
# 31  0.677934  42.0
# 39  0.672289  43.0
# 44  0.664957  44.0
# 34  0.660654  45.0

# %%
import pandas as pd
import re
import ast

# 定义文件路径
file_paths = {
    'KCAT': {
        'cv0': 'all_bianyiweidian_KCAT_cv0.txt',
        'cv1': 'all_bianyiweidian_KCAT_cv1.txt',
        'cv2': 'all_bianyiweidian_KCAT_cv2.txt',
        'cv3': 'all_bianyiweidian_KCAT_cv3.txt',
        'cv4': 'all_bianyiweidian_KCAT_cv4.txt'
    },
    'KM': {
        'cv0': 'all_bianyiweidian_KM_cv0.txt',
        'cv1': 'all_bianyiweidian_KM_cv1.txt',
        'cv2': 'all_bianyiweidian_KM_cv2.txt',
        'cv3': 'all_bianyiweidian_KM_cv3.txt',
        'cv4': 'all_bianyiweidian_KM_cv4.txt'
    },
    'KKM': {
        'cv0': 'all_bianyiweidian_KKM_cv0.txt',
        'cv1': 'all_bianyiweidian_KKM_cv1.txt',
        'cv2': 'all_bianyiweidian_KKM_cv2.txt',
        'cv3': 'all_bianyiweidian_KKM_cv3.txt',
        'cv4': 'all_bianyiweidian_KKM_cv4.txt'
    }
}

def process_file(file_path):
    """
    处理单个文件，提取模型名称和字典值。
    """
    with open(file_path, 'r') as file:
        content = file.read()

    # 正则表达式匹配模型名称和字典值
    pattern = re.compile(r'(\w+):\s*({.*?})')
    matches = pattern.findall(content)

    # 提取数据
    data = []
    for match in matches:
        model = match[0]
        try:
            dict_values = ast.literal_eval(match[1])  # 将字符串转换为字典
            data.append((model, dict_values))
        except (ValueError, SyntaxError):
            print(f"Warning: Could not parse dictionary for model {model} in file {file_path}")

    # 创建DataFrame
    df = pd.DataFrame(data, columns=['Model', 'Values'])
    return df

# 初始化存储每个类型的指标值的字典
type_metrics_data = {
    'KCAT': {},
    'KM': {},
    'KKM': {}
}

# 处理每个文件
for file_type, cv_files in file_paths.items():
    for cv, file_path in cv_files.items():
        # 处理文件
        df = process_file(file_path)
        # 将结果存储到 type_metrics_data 中
        for _, row in df.iterrows():
            model = row['Model']
            values = row['Values']
            if model not in type_metrics_data[file_type]:
                type_metrics_data[file_type][model] = []
            type_metrics_data[file_type][model].append(values)

# 计算每个类型的指标均值并排序
results = {}
for file_type, models_metrics in type_metrics_data.items():
    # 初始化存储每个键的均值
    mean_metrics = {key: {} for key in range(1, 7)}  # 1-6 的键

    # 计算每个模型的每个键的均值
    for model, metrics_list in models_metrics.items():
        for key in range(1, 7):
            # 提取当前键的所有值
            key_values = [metrics.get(key, None) for metrics in metrics_list]
            key_values = [v for v in key_values if v is not None]  # 过滤掉 None 值
            if key_values:  # 确保列表不为空
                mean_value = sum(key_values) / len(key_values)
                mean_metrics[key][model] = mean_value
            else:
                print(f"Warning: No valid values found for key {key} of model {model} in {file_type}")
                mean_metrics[key][model] = None  # 如果没有有效值，设置为 None

    # 对每个键的结果进行排序并计算排名
    ranked_results = {}
    for key, model_values in mean_metrics.items():
        # 创建 DataFrame
        df_mean_metrics = pd.DataFrame(list(model_values.items()), columns=['Model', f'Mean Value (Key {key})'])
        # 按 Mean Value 排序并计算排名
        df_mean_metrics = df_mean_metrics.sort_values(by=f'Mean Value (Key {key})', ascending=False)
        df_mean_metrics[f'Rank (Key {key})'] = df_mean_metrics[f'Mean Value (Key {key})'].rank(ascending=False, method='min')
        ranked_results[key] = df_mean_metrics

    # 存储结果
    results[file_type] = ranked_results

# 打印结果
for file_type, ranked_results in results.items():
    print(f"Results for {file_type}:")
    for key, df in ranked_results.items():
        print(f"\nKey {key}:")
        print(df)
    print("\n")

# 保存结果到 CSV 文件（可选）
for file_type, ranked_results in results.items():
    for key, df in ranked_results.items():
        df.to_csv(f'mean_values_rank_{file_type}_key{key}.csv', index=False)
# Out:
# Results for KCAT:
#
# Key 1:
#                        Model  Mean Value (Key 1)  Rank (Key 1)
# 22        unimolv2_esmc_KCAT            0.766154           1.0
# 27      chemberta2_esmc_KCAT            0.760972           2.0
# 7           molgen_esmc_KCAT            0.758348           3.0
# 23      unimolv2_prott5_KCAT            0.755732           4.0
# 28    chemberta2_prott5_KCAT            0.753947           5.0
# 2         smitrans_esmc_KCAT            0.751760           6.0
# 21        unimolv2_esm2_KCAT            0.749836           7.0
# 20       unimolv2_esm1b_KCAT            0.746023           8.0
# 26      chemberta2_esm2_KCAT            0.745054           9.0
# 17        unimolv1_esmc_KCAT            0.744836          10.0
# 8         molgen_prott5_KCAT            0.743927          11.0
# 25     chemberta2_esm1b_KCAT            0.741990          12.0
# 6           molgen_esm2_KCAT            0.741362          13.0
# 32            ecfp_esmc_KCAT            0.741034          14.0
# 3       smitrans_prott5_KCAT            0.739842          15.0
# 12        molebert_esmc_KCAT            0.737341          16.0
# 5          molgen_esm1b_KCAT            0.736930          17.0
# 18      unimolv1_prott5_KCAT            0.735913          18.0
# 33          ecfp_prott5_KCAT            0.735038          19.0
# 1         smitrans_esm2_KCAT            0.734747          20.0
# 0        smitrans_esm1b_KCAT            0.729418          21.0
# 13      molebert_prott5_KCAT            0.729196          22.0
# 16        unimolv1_esm2_KCAT            0.728744          23.0
# 31            ecfp_esm2_KCAT            0.727432          24.0
# 15       unimolv1_esm1b_KCAT            0.725908          25.0
# 30           ecfp_esm1b_KCAT            0.723185          26.0
# 11        molebert_esm2_KCAT            0.721382          27.0
# 37         rdkitfp_esmc_KCAT            0.719583          28.0
# 10       molebert_esm1b_KCAT            0.715838          29.0
# 42       maccskeys_esmc_KCAT            0.714524          30.0
# 43     maccskeys_prott5_KCAT            0.708739          31.0
# 38       rdkitfp_prott5_KCAT            0.707567          32.0
# 41       maccskeys_esm2_KCAT            0.700135          33.0
# 36         rdkitfp_esm2_KCAT            0.699845          34.0
# 40      maccskeys_esm1b_KCAT            0.697568          35.0
# 35        rdkitfp_esm1b_KCAT            0.696875          36.0
# 24    unimolv2_prollama_KCAT            0.695487          37.0
# 29  chemberta2_prollama_KCAT            0.691000          38.0
# 9       molgen_prollama_KCAT            0.679148          39.0
# 34        ecfp_prollama_KCAT            0.678779          40.0
# 14    molebert_prollama_KCAT            0.677148          41.0
# 19    unimolv1_prollama_KCAT            0.673544          42.0
# 4     smitrans_prollama_KCAT            0.672714          43.0
# 39     rdkitfp_prollama_KCAT            0.654526          44.0
# 44   maccskeys_prollama_KCAT            0.644339          45.0
#
# Key 2:
#                        Model  Mean Value (Key 2)  Rank (Key 2)
# 33          ecfp_prott5_KCAT            0.848557           1.0
# 31            ecfp_esm2_KCAT            0.845012           2.0
# 38       rdkitfp_prott5_KCAT            0.840985           3.0
# 36         rdkitfp_esm2_KCAT            0.839398           4.0
# 32            ecfp_esmc_KCAT            0.839332           5.0
# 23      unimolv2_prott5_KCAT            0.838151           6.0
# 43     maccskeys_prott5_KCAT            0.837691           7.0
# 17        unimolv1_esmc_KCAT            0.836225           8.0
# 22        unimolv2_esmc_KCAT            0.835104           9.0
# 21        unimolv2_esm2_KCAT            0.835064          10.0
# 16        unimolv1_esm2_KCAT            0.834921          11.0
# 30           ecfp_esm1b_KCAT            0.834883          12.0
# 15       unimolv1_esm1b_KCAT            0.834553          13.0
# 11        molebert_esm2_KCAT            0.834536          14.0
# 41       maccskeys_esm2_KCAT            0.833784          15.0
# 35        rdkitfp_esm1b_KCAT            0.833474          16.0
# 37         rdkitfp_esmc_KCAT            0.833247          17.0
# 18      unimolv1_prott5_KCAT            0.832900          18.0
# 10       molebert_esm1b_KCAT            0.831282          19.0
# 40      maccskeys_esm1b_KCAT            0.830615          20.0
# 13      molebert_prott5_KCAT            0.830559          21.0
# 28    chemberta2_prott5_KCAT            0.830243          22.0
# 20       unimolv2_esm1b_KCAT            0.828706          23.0
# 42       maccskeys_esmc_KCAT            0.828552          24.0
# 12        molebert_esmc_KCAT            0.827902          25.0
# 26      chemberta2_esm2_KCAT            0.827565          26.0
# 6           molgen_esm2_KCAT            0.826843          27.0
# 0        smitrans_esm1b_KCAT            0.826634          28.0
# 8         molgen_prott5_KCAT            0.826340          29.0
# 25     chemberta2_esm1b_KCAT            0.826053          30.0
# 1         smitrans_esm2_KCAT            0.826013          31.0
# 5          molgen_esm1b_KCAT            0.825515          32.0
# 27      chemberta2_esmc_KCAT            0.825325          33.0
# 2         smitrans_esmc_KCAT            0.824079          34.0
# 7           molgen_esmc_KCAT            0.823942          35.0
# 3       smitrans_prott5_KCAT            0.823378          36.0
# 34        ecfp_prollama_KCAT            0.816996          37.0
# 14    molebert_prollama_KCAT            0.812372          38.0
# 19    unimolv1_prollama_KCAT            0.810832          39.0
# 24    unimolv2_prollama_KCAT            0.809246          40.0
# 39     rdkitfp_prollama_KCAT            0.805234          41.0
# 44   maccskeys_prollama_KCAT            0.800850          42.0
# 9       molgen_prollama_KCAT            0.798751          43.0
# 29  chemberta2_prollama_KCAT            0.796462          44.0
# 4     smitrans_prollama_KCAT            0.796430          45.0
#
# Key 3:
#                        Model  Mean Value (Key 3)  Rank (Key 3)
# 12        molebert_esmc_KCAT            0.877786           1.0
# 31            ecfp_esm2_KCAT            0.877610           2.0
# 35        rdkitfp_esm1b_KCAT            0.875272           3.0
# 10       molebert_esm1b_KCAT            0.874594           4.0
# 36         rdkitfp_esm2_KCAT            0.874567           5.0
# 22        unimolv2_esmc_KCAT            0.873786           6.0
# 37         rdkitfp_esmc_KCAT            0.872957           7.0
# 11        molebert_esm2_KCAT            0.872740           8.0
# 30           ecfp_esm1b_KCAT            0.872523           9.0
# 6           molgen_esm2_KCAT            0.871612          10.0
# 32            ecfp_esmc_KCAT            0.871305          11.0
# 33          ecfp_prott5_KCAT            0.870194          12.0
# 21        unimolv2_esm2_KCAT            0.869688          13.0
# 7           molgen_esmc_KCAT            0.869305          14.0
# 13      molebert_prott5_KCAT            0.868318          15.0
# 15       unimolv1_esm1b_KCAT            0.868129          16.0
# 17        unimolv1_esmc_KCAT            0.866199          17.0
# 26      chemberta2_esm2_KCAT            0.866042          18.0
# 20       unimolv2_esm1b_KCAT            0.865994          19.0
# 38       rdkitfp_prott5_KCAT            0.865888          20.0
# 16        unimolv1_esm2_KCAT            0.865124          21.0
# 5          molgen_esm1b_KCAT            0.864641          22.0
# 2         smitrans_esmc_KCAT            0.863994          23.0
# 25     chemberta2_esm1b_KCAT            0.862722          24.0
# 8         molgen_prott5_KCAT            0.860393          25.0
# 27      chemberta2_esmc_KCAT            0.859623          26.0
# 0        smitrans_esm1b_KCAT            0.859397          27.0
# 42       maccskeys_esmc_KCAT            0.856758          28.0
# 1         smitrans_esm2_KCAT            0.856057          29.0
# 23      unimolv2_prott5_KCAT            0.855696          30.0
# 18      unimolv1_prott5_KCAT            0.854698          31.0
# 41       maccskeys_esm2_KCAT            0.851623          32.0
# 28    chemberta2_prott5_KCAT            0.847478          33.0
# 40      maccskeys_esm1b_KCAT            0.843410          34.0
# 3       smitrans_prott5_KCAT            0.838567          35.0
# 14    molebert_prollama_KCAT            0.828928          36.0
# 43     maccskeys_prott5_KCAT            0.824040          37.0
# 34        ecfp_prollama_KCAT            0.820103          38.0
# 39     rdkitfp_prollama_KCAT            0.818478          39.0
# 19    unimolv1_prollama_KCAT            0.817987          40.0
# 9       molgen_prollama_KCAT            0.816892          41.0
# 24    unimolv2_prollama_KCAT            0.813138          42.0
# 29  chemberta2_prollama_KCAT            0.812079          43.0
# 44   maccskeys_prollama_KCAT            0.800520          44.0
# 4     smitrans_prollama_KCAT            0.798688          45.0
#
# Key 4:
#                        Model  Mean Value (Key 4)  Rank (Key 4)
# 43     maccskeys_prott5_KCAT            0.818902           1.0
# 31            ecfp_esm2_KCAT            0.818225           2.0
# 41       maccskeys_esm2_KCAT            0.816810           3.0
# 30           ecfp_esm1b_KCAT            0.815352           4.0
# 33          ecfp_prott5_KCAT            0.811025           5.0
# 16        unimolv1_esm2_KCAT            0.808086           6.0
# 23      unimolv2_prott5_KCAT            0.807267           7.0
# 42       maccskeys_esmc_KCAT            0.806980           8.0
# 40      maccskeys_esm1b_KCAT            0.806522           9.0
# 32            ecfp_esmc_KCAT            0.805496          10.0
# 21        unimolv2_esm2_KCAT            0.804727          11.0
# 18      unimolv1_prott5_KCAT            0.803921          12.0
# 28    chemberta2_prott5_KCAT            0.803490          13.0
# 3       smitrans_prott5_KCAT            0.803421          14.0
# 25     chemberta2_esm1b_KCAT            0.800669          15.0
# 17        unimolv1_esmc_KCAT            0.800452          16.0
# 1         smitrans_esm2_KCAT            0.799543          17.0
# 11        molebert_esm2_KCAT            0.797732          18.0
# 22        unimolv2_esmc_KCAT            0.797144          19.0
# 15       unimolv1_esm1b_KCAT            0.795830          20.0
# 38       rdkitfp_prott5_KCAT            0.795025          21.0
# 13      molebert_prott5_KCAT            0.793997          22.0
# 0        smitrans_esm1b_KCAT            0.793528          23.0
# 7           molgen_esmc_KCAT            0.792759          24.0
# 37         rdkitfp_esmc_KCAT            0.792389          25.0
# 2         smitrans_esmc_KCAT            0.791981          26.0
# 10       molebert_esm1b_KCAT            0.791337          27.0
# 8         molgen_prott5_KCAT            0.790920          28.0
# 36         rdkitfp_esm2_KCAT            0.790312          29.0
# 20       unimolv2_esm1b_KCAT            0.788218          30.0
# 6           molgen_esm2_KCAT            0.787478          31.0
# 12        molebert_esmc_KCAT            0.787160          32.0
# 26      chemberta2_esm2_KCAT            0.787037          33.0
# 44   maccskeys_prollama_KCAT            0.786861          34.0
# 35        rdkitfp_esm1b_KCAT            0.786397          35.0
# 34        ecfp_prollama_KCAT            0.785619          36.0
# 27      chemberta2_esmc_KCAT            0.782942          37.0
# 5          molgen_esm1b_KCAT            0.778412          38.0
# 24    unimolv2_prollama_KCAT            0.773208          39.0
# 39     rdkitfp_prollama_KCAT            0.769586          40.0
# 19    unimolv1_prollama_KCAT            0.768951          41.0
# 14    molebert_prollama_KCAT            0.768723          42.0
# 29  chemberta2_prollama_KCAT            0.757793          43.0
# 4     smitrans_prollama_KCAT            0.749819          44.0
# 9       molgen_prollama_KCAT            0.742615          45.0
#
# Key 5:
#                        Model  Mean Value (Key 5)  Rank (Key 5)
# 33          ecfp_prott5_KCAT            0.825328           1.0
# 31            ecfp_esm2_KCAT            0.812216           2.0
# 30           ecfp_esm1b_KCAT            0.807530           3.0
# 18      unimolv1_prott5_KCAT            0.800028           4.0
# 38       rdkitfp_prott5_KCAT            0.792097           5.0
# 10       molebert_esm1b_KCAT            0.789166           6.0
# 20       unimolv2_esm1b_KCAT            0.787415           7.0
# 8         molgen_prott5_KCAT            0.786507           8.0
# 17        unimolv1_esmc_KCAT            0.784353           9.0
# 23      unimolv2_prott5_KCAT            0.781430          10.0
# 6           molgen_esm2_KCAT            0.778468          11.0
# 15       unimolv1_esm1b_KCAT            0.777043          12.0
# 16        unimolv1_esm2_KCAT            0.775928          13.0
# 22        unimolv2_esmc_KCAT            0.775627          14.0
# 12        molebert_esmc_KCAT            0.775417          15.0
# 36         rdkitfp_esm2_KCAT            0.775323          16.0
# 11        molebert_esm2_KCAT            0.769184          17.0
# 32            ecfp_esmc_KCAT            0.768466          18.0
# 21        unimolv2_esm2_KCAT            0.768421          19.0
# 26      chemberta2_esm2_KCAT            0.768224          20.0
# 27      chemberta2_esmc_KCAT            0.766716          21.0
# 35        rdkitfp_esm1b_KCAT            0.765883          22.0
# 2         smitrans_esmc_KCAT            0.763738          23.0
# 5          molgen_esm1b_KCAT            0.762298          24.0
# 3       smitrans_prott5_KCAT            0.761602          25.0
# 37         rdkitfp_esmc_KCAT            0.761535          26.0
# 25     chemberta2_esm1b_KCAT            0.760555          27.0
# 13      molebert_prott5_KCAT            0.757785          28.0
# 28    chemberta2_prott5_KCAT            0.757718          29.0
# 43     maccskeys_prott5_KCAT            0.756641          30.0
# 1         smitrans_esm2_KCAT            0.755312          31.0
# 41       maccskeys_esm2_KCAT            0.753749          32.0
# 7           molgen_esmc_KCAT            0.753494          33.0
# 0        smitrans_esm1b_KCAT            0.747185          34.0
# 40      maccskeys_esm1b_KCAT            0.720976          35.0
# 42       maccskeys_esmc_KCAT            0.716277          36.0
# 19    unimolv1_prollama_KCAT            0.615543          37.0
# 34        ecfp_prollama_KCAT            0.614618          38.0
# 14    molebert_prollama_KCAT            0.580652          39.0
# 4     smitrans_prollama_KCAT            0.580211          40.0
# 44   maccskeys_prollama_KCAT            0.575347          41.0
# 24    unimolv2_prollama_KCAT            0.558628          42.0
# 29  chemberta2_prollama_KCAT            0.554952          43.0
# 9       molgen_prollama_KCAT            0.548330          44.0
# 39     rdkitfp_prollama_KCAT            0.504642          45.0
#
# Key 6:
#                        Model  Mean Value (Key 6)  Rank (Key 6)
# 25     chemberta2_esm1b_KCAT            0.833669           1.0
# 30           ecfp_esm1b_KCAT            0.832954           2.0
# 10       molebert_esm1b_KCAT            0.829612           3.0
# 13      molebert_prott5_KCAT            0.822137           4.0
# 11        molebert_esm2_KCAT            0.820636           5.0
# 33          ecfp_prott5_KCAT            0.818062           6.0
# 31            ecfp_esm2_KCAT            0.817815           7.0
# 5          molgen_esm1b_KCAT            0.816285           8.0
# 26      chemberta2_esm2_KCAT            0.814409           9.0
# 15       unimolv1_esm1b_KCAT            0.808548          10.0
# 6           molgen_esm2_KCAT            0.806856          11.0
# 0        smitrans_esm1b_KCAT            0.805345          12.0
# 1         smitrans_esm2_KCAT            0.804960          13.0
# 32            ecfp_esmc_KCAT            0.804867          14.0
# 28    chemberta2_prott5_KCAT            0.801704          15.0
# 38       rdkitfp_prott5_KCAT            0.800834          16.0
# 35        rdkitfp_esm1b_KCAT            0.799059          17.0
# 7           molgen_esmc_KCAT            0.797059          18.0
# 12        molebert_esmc_KCAT            0.793919          19.0
# 36         rdkitfp_esm2_KCAT            0.793054          20.0
# 16        unimolv1_esm2_KCAT            0.789206          21.0
# 3       smitrans_prott5_KCAT            0.786388          22.0
# 2         smitrans_esmc_KCAT            0.786136          23.0
# 27      chemberta2_esmc_KCAT            0.785380          24.0
# 8         molgen_prott5_KCAT            0.784638          25.0
# 18      unimolv1_prott5_KCAT            0.781253          26.0
# 14    molebert_prollama_KCAT            0.776356          27.0
# 29  chemberta2_prollama_KCAT            0.773290          28.0
# 9       molgen_prollama_KCAT            0.773235          29.0
# 37         rdkitfp_esmc_KCAT            0.769535          30.0
# 19    unimolv1_prollama_KCAT            0.766245          31.0
# 34        ecfp_prollama_KCAT            0.764419          32.0
# 17        unimolv1_esmc_KCAT            0.763385          33.0
# 20       unimolv2_esm1b_KCAT            0.760801          34.0
# 21        unimolv2_esm2_KCAT            0.759137          35.0
# 41       maccskeys_esm2_KCAT            0.758346          36.0
# 22        unimolv2_esmc_KCAT            0.751515          37.0
# 23      unimolv2_prott5_KCAT            0.750710          38.0
# 39     rdkitfp_prollama_KCAT            0.750325          39.0
# 40      maccskeys_esm1b_KCAT            0.750198          40.0
# 43     maccskeys_prott5_KCAT            0.746932          41.0
# 4     smitrans_prollama_KCAT            0.745113          42.0
# 42       maccskeys_esmc_KCAT            0.733119          43.0
# 24    unimolv2_prollama_KCAT            0.723584          44.0
# 44   maccskeys_prollama_KCAT            0.690226          45.0
#
#
# Results for KM:
#
# Key 1:
#                      Model  Mean Value (Key 1)  Rank (Key 1)
# 17        unimolv1_esmc_KM            0.810786           1.0
# 18      unimolv1_prott5_KM            0.810616           2.0
# 8         molgen_prott5_KM            0.810400           3.0
# 7           molgen_esmc_KM            0.810067           4.0
# 2         smitrans_esmc_KM            0.810016           5.0
# 3       smitrans_prott5_KM            0.809419           6.0
# 23      unimolv2_prott5_KM            0.809352           7.0
# 28    chemberta2_prott5_KM            0.808371           8.0
# 27      chemberta2_esmc_KM            0.807742           9.0
# 22        unimolv2_esmc_KM            0.807497          10.0
# 12        molebert_esmc_KM            0.806125          11.0
# 13      molebert_prott5_KM            0.805838          12.0
# 6           molgen_esm2_KM            0.805337          13.0
# 16        unimolv1_esm2_KM            0.804565          14.0
# 21        unimolv2_esm2_KM            0.803978          15.0
# 15       unimolv1_esm1b_KM            0.802693          16.0
# 1         smitrans_esm2_KM            0.802494          17.0
# 26      chemberta2_esm2_KM            0.802478          18.0
# 20       unimolv2_esm1b_KM            0.801914          19.0
# 0        smitrans_esm1b_KM            0.801402          20.0
# 5          molgen_esm1b_KM            0.801379          21.0
# 11        molebert_esm2_KM            0.801378          22.0
# 25     chemberta2_esm1b_KM            0.800944          23.0
# 10       molebert_esm1b_KM            0.797246          24.0
# 32            ecfp_esmc_KM            0.793749          25.0
# 33          ecfp_prott5_KM            0.793416          26.0
# 31            ecfp_esm2_KM            0.792073          27.0
# 4     smitrans_prollama_KM            0.788599          28.0
# 9       molgen_prollama_KM            0.787953          29.0
# 38       rdkitfp_prott5_KM            0.787633          30.0
# 30           ecfp_esm1b_KM            0.787612          31.0
# 41       maccskeys_esm2_KM            0.786251          32.0
# 43     maccskeys_prott5_KM            0.785997          33.0
# 37         rdkitfp_esmc_KM            0.785877          34.0
# 19    unimolv1_prollama_KM            0.785033          35.0
# 29  chemberta2_prollama_KM            0.784788          36.0
# 24    unimolv2_prollama_KM            0.784760          37.0
# 42       maccskeys_esmc_KM            0.783485          38.0
# 14    molebert_prollama_KM            0.781191          39.0
# 36         rdkitfp_esm2_KM            0.780527          40.0
# 40      maccskeys_esm1b_KM            0.779214          41.0
# 35        rdkitfp_esm1b_KM            0.777111          42.0
# 34        ecfp_prollama_KM            0.760935          43.0
# 39     rdkitfp_prollama_KM            0.754398          44.0
# 44   maccskeys_prollama_KM            0.749759          45.0
#
# Key 2:
#                      Model  Mean Value (Key 2)  Rank (Key 2)
# 33          ecfp_prott5_KM            0.775218           1.0
# 30           ecfp_esm1b_KM            0.770814           2.0
# 23      unimolv2_prott5_KM            0.767461           3.0
# 31            ecfp_esm2_KM            0.766284           4.0
# 18      unimolv1_prott5_KM            0.765720           5.0
# 32            ecfp_esmc_KM            0.764792           6.0
# 19    unimolv1_prollama_KM            0.764474           7.0
# 17        unimolv1_esmc_KM            0.763358           8.0
# 8         molgen_prott5_KM            0.761573           9.0
# 20       unimolv2_esm1b_KM            0.760860          10.0
# 22        unimolv2_esmc_KM            0.760706          11.0
# 9       molgen_prollama_KM            0.759464          12.0
# 43     maccskeys_prott5_KM            0.758422          13.0
# 15       unimolv1_esm1b_KM            0.757550          14.0
# 7           molgen_esmc_KM            0.755374          15.0
# 24    unimolv2_prollama_KM            0.755094          16.0
# 34        ecfp_prollama_KM            0.754066          17.0
# 3       smitrans_prott5_KM            0.753909          18.0
# 40      maccskeys_esm1b_KM            0.753660          19.0
# 5          molgen_esm1b_KM            0.752542          20.0
# 28    chemberta2_prott5_KM            0.751979          21.0
# 27      chemberta2_esmc_KM            0.751667          22.0
# 2         smitrans_esmc_KM            0.751532          23.0
# 4     smitrans_prollama_KM            0.751348          24.0
# 21        unimolv2_esm2_KM            0.750354          25.0
# 13      molebert_prott5_KM            0.749688          26.0
# 16        unimolv1_esm2_KM            0.749558          27.0
# 6           molgen_esm2_KM            0.749319          28.0
# 0        smitrans_esm1b_KM            0.748196          29.0
# 29  chemberta2_prollama_KM            0.747795          30.0
# 25     chemberta2_esm1b_KM            0.747403          31.0
# 14    molebert_prollama_KM            0.747314          32.0
# 41       maccskeys_esm2_KM            0.744543          33.0
# 42       maccskeys_esmc_KM            0.744220          34.0
# 1         smitrans_esm2_KM            0.743469          35.0
# 10       molebert_esm1b_KM            0.743445          36.0
# 12        molebert_esmc_KM            0.740534          37.0
# 26      chemberta2_esm2_KM            0.739627          38.0
# 11        molebert_esm2_KM            0.735706          39.0
# 44   maccskeys_prollama_KM            0.734243          40.0
# 38       rdkitfp_prott5_KM            0.728835          41.0
# 35        rdkitfp_esm1b_KM            0.723578          42.0
# 37         rdkitfp_esmc_KM            0.719579          43.0
# 39     rdkitfp_prollama_KM            0.718723          44.0
# 36         rdkitfp_esm2_KM            0.714135          45.0
#
# Key 3:
#                      Model  Mean Value (Key 3)  Rank (Key 3)
# 31            ecfp_esm2_KM            0.863187           1.0
# 21        unimolv2_esm2_KM            0.862865           2.0
# 10       molebert_esm1b_KM            0.861466           3.0
# 6           molgen_esm2_KM            0.861086           4.0
# 1         smitrans_esm2_KM            0.859379           5.0
# 27      chemberta2_esmc_KM            0.859314           6.0
# 5          molgen_esm1b_KM            0.858909           7.0
# 30           ecfp_esm1b_KM            0.858024           8.0
# 7           molgen_esmc_KM            0.857792           9.0
# 25     chemberta2_esm1b_KM            0.857322          10.0
# 14    molebert_prollama_KM            0.857178          11.0
# 11        molebert_esm2_KM            0.857045          12.0
# 2         smitrans_esmc_KM            0.856650          13.0
# 20       unimolv2_esm1b_KM            0.856430          14.0
# 16        unimolv1_esm2_KM            0.856231          15.0
# 0        smitrans_esm1b_KM            0.856201          16.0
# 9       molgen_prollama_KM            0.856170          17.0
# 12        molebert_esmc_KM            0.854751          18.0
# 26      chemberta2_esm2_KM            0.853894          19.0
# 17        unimolv1_esmc_KM            0.853284          20.0
# 4     smitrans_prollama_KM            0.852596          21.0
# 22        unimolv2_esmc_KM            0.852358          22.0
# 33          ecfp_prott5_KM            0.852081          23.0
# 29  chemberta2_prollama_KM            0.850266          24.0
# 19    unimolv1_prollama_KM            0.850117          25.0
# 15       unimolv1_esm1b_KM            0.849961          26.0
# 24    unimolv2_prollama_KM            0.848706          27.0
# 41       maccskeys_esm2_KM            0.845608          28.0
# 3       smitrans_prott5_KM            0.844455          29.0
# 13      molebert_prott5_KM            0.843365          30.0
# 8         molgen_prott5_KM            0.842724          31.0
# 32            ecfp_esmc_KM            0.840341          32.0
# 40      maccskeys_esm1b_KM            0.839852          33.0
# 18      unimolv1_prott5_KM            0.837972          34.0
# 28    chemberta2_prott5_KM            0.837584          35.0
# 23      unimolv2_prott5_KM            0.836370          36.0
# 36         rdkitfp_esm2_KM            0.834537          37.0
# 43     maccskeys_prott5_KM            0.831592          38.0
# 34        ecfp_prollama_KM            0.829350          39.0
# 39     rdkitfp_prollama_KM            0.824709          40.0
# 37         rdkitfp_esmc_KM            0.822745          41.0
# 42       maccskeys_esmc_KM            0.822560          42.0
# 35        rdkitfp_esm1b_KM            0.820956          43.0
# 38       rdkitfp_prott5_KM            0.817879          44.0
# 44   maccskeys_prollama_KM            0.802999          45.0
#
# Key 4:
#                      Model  Mean Value (Key 4)  Rank (Key 4)
# 27      chemberta2_esmc_KM            0.818487           1.0
# 2         smitrans_esmc_KM            0.818360           2.0
# 7           molgen_esmc_KM            0.812186           3.0
# 17        unimolv1_esmc_KM            0.809014           4.0
# 15       unimolv1_esm1b_KM            0.805980           5.0
# 5          molgen_esm1b_KM            0.805642           6.0
# 20       unimolv2_esm1b_KM            0.804276           7.0
# 0        smitrans_esm1b_KM            0.800356           8.0
# 3       smitrans_prott5_KM            0.800272           9.0
# 18      unimolv1_prott5_KM            0.800208          10.0
# 29  chemberta2_prollama_KM            0.799415          11.0
# 25     chemberta2_esm1b_KM            0.799224          12.0
# 9       molgen_prollama_KM            0.798302          13.0
# 16        unimolv1_esm2_KM            0.797594          14.0
# 28    chemberta2_prott5_KM            0.796666          15.0
# 8         molgen_prott5_KM            0.796045          16.0
# 22        unimolv2_esmc_KM            0.794339          17.0
# 1         smitrans_esm2_KM            0.793392          18.0
# 23      unimolv2_prott5_KM            0.787513          19.0
# 6           molgen_esm2_KM            0.786923          20.0
# 26      chemberta2_esm2_KM            0.784811          21.0
# 19    unimolv1_prollama_KM            0.784403          22.0
# 4     smitrans_prollama_KM            0.783003          23.0
# 12        molebert_esmc_KM            0.777909          24.0
# 21        unimolv2_esm2_KM            0.777404          25.0
# 24    unimolv2_prollama_KM            0.776838          26.0
# 37         rdkitfp_esmc_KM            0.770444          27.0
# 40      maccskeys_esm1b_KM            0.766700          28.0
# 43     maccskeys_prott5_KM            0.766215          29.0
# 42       maccskeys_esmc_KM            0.760975          30.0
# 13      molebert_prott5_KM            0.760919          31.0
# 38       rdkitfp_prott5_KM            0.759068          32.0
# 30           ecfp_esm1b_KM            0.757700          33.0
# 10       molebert_esm1b_KM            0.754860          34.0
# 35        rdkitfp_esm1b_KM            0.753616          35.0
# 41       maccskeys_esm2_KM            0.753121          36.0
# 36         rdkitfp_esm2_KM            0.744707          37.0
# 14    molebert_prollama_KM            0.743248          38.0
# 31            ecfp_esm2_KM            0.741131          39.0
# 33          ecfp_prott5_KM            0.740460          40.0
# 32            ecfp_esmc_KM            0.739874          41.0
# 11        molebert_esm2_KM            0.739429          42.0
# 44   maccskeys_prollama_KM            0.735761          43.0
# 39     rdkitfp_prollama_KM            0.715581          44.0
# 34        ecfp_prollama_KM            0.702604          45.0
#
# Key 5:
#                      Model  Mean Value (Key 5)  Rank (Key 5)
# 34        ecfp_prollama_KM            0.871967           1.0
# 44   maccskeys_prollama_KM            0.858390           2.0
# 43     maccskeys_prott5_KM            0.772890           3.0
# 33          ecfp_prott5_KM            0.766323           4.0
# 32            ecfp_esmc_KM            0.742900           5.0
# 42       maccskeys_esmc_KM            0.724813           6.0
# 41       maccskeys_esm2_KM            0.714391           7.0
# 39     rdkitfp_prollama_KM            0.710095           8.0
# 31            ecfp_esm2_KM            0.698959           9.0
# 40      maccskeys_esm1b_KM            0.694119          10.0
# 30           ecfp_esm1b_KM            0.680380          11.0
# 37         rdkitfp_esmc_KM            0.637535          12.0
# 22        unimolv2_esmc_KM            0.635404          13.0
# 23      unimolv2_prott5_KM            0.612148          14.0
# 7           molgen_esmc_KM            0.601959          15.0
# 3       smitrans_prott5_KM            0.595220          16.0
# 17        unimolv1_esmc_KM            0.591065          17.0
# 36         rdkitfp_esm2_KM            0.585988          18.0
# 38       rdkitfp_prott5_KM            0.581571          19.0
# 2         smitrans_esmc_KM            0.574565          20.0
# 1         smitrans_esm2_KM            0.563796          21.0
# 8         molgen_prott5_KM            0.563083          22.0
# 18      unimolv1_prott5_KM            0.562312          23.0
# 27      chemberta2_esmc_KM            0.558257          24.0
# 11        molebert_esm2_KM            0.555614          25.0
# 12        molebert_esmc_KM            0.553984          26.0
# 21        unimolv2_esm2_KM            0.553352          27.0
# 20       unimolv2_esm1b_KM            0.550143          28.0
# 13      molebert_prott5_KM            0.548421          29.0
# 10       molebert_esm1b_KM            0.542323          30.0
# 6           molgen_esm2_KM            0.541403          31.0
# 35        rdkitfp_esm1b_KM            0.540398          32.0
# 28    chemberta2_prott5_KM            0.538056          33.0
# 26      chemberta2_esm2_KM            0.528834          34.0
# 16        unimolv1_esm2_KM            0.528482          35.0
# 25     chemberta2_esm1b_KM            0.521487          36.0
# 15       unimolv1_esm1b_KM            0.515903          37.0
# 5          molgen_esm1b_KM            0.511619          38.0
# 0        smitrans_esm1b_KM            0.508035          39.0
# 4     smitrans_prollama_KM            0.502296          40.0
# 24    unimolv2_prollama_KM            0.477446          41.0
# 14    molebert_prollama_KM            0.347248          42.0
# 9       molgen_prollama_KM            0.310794          43.0
# 19    unimolv1_prollama_KM            0.310390          44.0
# 29  chemberta2_prollama_KM            0.289725          45.0
#
# Key 6:
#                      Model  Mean Value (Key 6)  Rank (Key 6)
# 12        molebert_esmc_KM            0.827359           1.0
# 37         rdkitfp_esmc_KM            0.811623           2.0
# 10       molebert_esm1b_KM            0.808838           3.0
# 36         rdkitfp_esm2_KM            0.804627           4.0
# 42       maccskeys_esmc_KM            0.801672           5.0
# 7           molgen_esmc_KM            0.796704           6.0
# 31            ecfp_esm2_KM            0.795059           7.0
# 35        rdkitfp_esm1b_KM            0.792531           8.0
# 11        molebert_esm2_KM            0.786576           9.0
# 6           molgen_esm2_KM            0.786088          10.0
# 17        unimolv1_esmc_KM            0.785458          11.0
# 1         smitrans_esm2_KM            0.784351          12.0
# 30           ecfp_esm1b_KM            0.781501          13.0
# 32            ecfp_esmc_KM            0.778290          14.0
# 20       unimolv2_esm1b_KM            0.774849          15.0
# 2         smitrans_esmc_KM            0.774504          16.0
# 33          ecfp_prott5_KM            0.770450          17.0
# 22        unimolv2_esmc_KM            0.770382          18.0
# 16        unimolv1_esm2_KM            0.770062          19.0
# 38       rdkitfp_prott5_KM            0.769890          20.0
# 27      chemberta2_esmc_KM            0.768857          21.0
# 13      molebert_prott5_KM            0.765468          22.0
# 41       maccskeys_esm2_KM            0.764842          23.0
# 21        unimolv2_esm2_KM            0.764226          24.0
# 43     maccskeys_prott5_KM            0.763025          25.0
# 5          molgen_esm1b_KM            0.762570          26.0
# 40      maccskeys_esm1b_KM            0.758719          27.0
# 26      chemberta2_esm2_KM            0.756258          28.0
# 0        smitrans_esm1b_KM            0.745299          29.0
# 28    chemberta2_prott5_KM            0.743873          30.0
# 25     chemberta2_esm1b_KM            0.740279          31.0
# 8         molgen_prott5_KM            0.739276          32.0
# 3       smitrans_prott5_KM            0.737153          33.0
# 23      unimolv2_prott5_KM            0.736771          34.0
# 18      unimolv1_prott5_KM            0.731924          35.0
# 15       unimolv1_esm1b_KM            0.723871          36.0
# 14    molebert_prollama_KM            0.629826          37.0
# 19    unimolv1_prollama_KM            0.623079          38.0
# 9       molgen_prollama_KM            0.606220          39.0
# 39     rdkitfp_prollama_KM            0.604182          40.0
# 29  chemberta2_prollama_KM            0.602839          41.0
# 4     smitrans_prollama_KM            0.601820          42.0
# 24    unimolv2_prollama_KM            0.601711          43.0
# 34        ecfp_prollama_KM            0.575401          44.0
# 44   maccskeys_prollama_KM            0.553835          45.0
#
#
# Results for KKM:
#
# Key 1:
#                       Model  Mean Value (Key 1)  Rank (Key 1)
# 17        unimolv1_esmc_KKM            0.710984           1.0
# 18      unimolv1_prott5_KKM            0.709165           2.0
# 2         smitrans_esmc_KKM            0.708328           3.0
# 23      unimolv2_prott5_KKM            0.706327           4.0
# 22        unimolv2_esmc_KKM            0.706194           5.0
# 8         molgen_prott5_KKM            0.705991           6.0
# 7           molgen_esmc_KKM            0.705285           7.0
# 3       smitrans_prott5_KKM            0.702490           8.0
# 27      chemberta2_esmc_KKM            0.702435           9.0
# 12        molebert_esmc_KKM            0.701850          10.0
# 28    chemberta2_prott5_KKM            0.701390          11.0
# 13      molebert_prott5_KKM            0.700416          12.0
# 16        unimolv1_esm2_KKM            0.698330          13.0
# 21        unimolv2_esm2_KKM            0.696360          14.0
# 20       unimolv2_esm1b_KKM            0.694264          15.0
# 1         smitrans_esm2_KKM            0.693987          16.0
# 6           molgen_esm2_KKM            0.692764          17.0
# 15       unimolv1_esm1b_KKM            0.692718          18.0
# 26      chemberta2_esm2_KKM            0.691375          19.0
# 5          molgen_esm1b_KKM            0.690496          20.0
# 0        smitrans_esm1b_KKM            0.689196          21.0
# 11        molebert_esm2_KKM            0.688739          22.0
# 33          ecfp_prott5_KKM            0.688660          23.0
# 32            ecfp_esmc_KKM            0.688256          24.0
# 38       rdkitfp_prott5_KKM            0.688025          25.0
# 37         rdkitfp_esmc_KKM            0.687409          26.0
# 10       molebert_esm1b_KKM            0.685947          27.0
# 25     chemberta2_esm1b_KKM            0.685532          28.0
# 30           ecfp_esm1b_KKM            0.678730          29.0
# 31            ecfp_esm2_KKM            0.675787          30.0
# 36         rdkitfp_esm2_KKM            0.674521          31.0
# 43     maccskeys_prott5_KKM            0.671525          32.0
# 35        rdkitfp_esm1b_KKM            0.670867          33.0
# 42       maccskeys_esmc_KKM            0.666700          34.0
# 40      maccskeys_esm1b_KKM            0.659429          35.0
# 41       maccskeys_esm2_KKM            0.657841          36.0
# 24    unimolv2_prollama_KKM            0.648600          37.0
# 9       molgen_prollama_KKM            0.646863          38.0
# 4     smitrans_prollama_KKM            0.646320          39.0
# 19    unimolv1_prollama_KKM            0.646072          40.0
# 14    molebert_prollama_KKM            0.644772          41.0
# 29  chemberta2_prollama_KKM            0.638427          42.0
# 34        ecfp_prollama_KKM            0.618735          43.0
# 39     rdkitfp_prollama_KKM            0.616584          44.0
# 44   maccskeys_prollama_KKM            0.600516          45.0
#
# Key 2:
#                       Model  Mean Value (Key 2)  Rank (Key 2)
# 23      unimolv2_prott5_KKM            0.748713           1.0
# 8         molgen_prott5_KKM            0.747983           2.0
# 43     maccskeys_prott5_KKM            0.746241           3.0
# 18      unimolv1_prott5_KKM            0.744571           4.0
# 28    chemberta2_prott5_KKM            0.743882           5.0
# 13      molebert_prott5_KKM            0.740741           6.0
# 7           molgen_esmc_KKM            0.737469           7.0
# 5          molgen_esm1b_KKM            0.736026           8.0
# 16        unimolv1_esm2_KKM            0.735783           9.0
# 3       smitrans_prott5_KKM            0.733477          10.0
# 20       unimolv2_esm1b_KKM            0.731625          11.0
# 6           molgen_esm2_KKM            0.731024          12.0
# 2         smitrans_esmc_KKM            0.730497          13.0
# 27      chemberta2_esmc_KKM            0.730345          14.0
# 42       maccskeys_esmc_KKM            0.730140          15.0
# 26      chemberta2_esm2_KKM            0.729884          16.0
# 22        unimolv2_esmc_KKM            0.728658          17.0
# 0        smitrans_esm1b_KKM            0.728512          18.0
# 12        molebert_esmc_KKM            0.728307          19.0
# 17        unimolv1_esmc_KKM            0.728262          20.0
# 25     chemberta2_esm1b_KKM            0.727620          21.0
# 21        unimolv2_esm2_KKM            0.727614          22.0
# 19    unimolv1_prollama_KKM            0.726313          23.0
# 24    unimolv2_prollama_KKM            0.725313          24.0
# 44   maccskeys_prollama_KKM            0.724145          25.0
# 11        molebert_esm2_KKM            0.723625          26.0
# 15       unimolv1_esm1b_KKM            0.722951          27.0
# 10       molebert_esm1b_KKM            0.722271          28.0
# 1         smitrans_esm2_KKM            0.721931          29.0
# 14    molebert_prollama_KKM            0.719215          30.0
# 40      maccskeys_esm1b_KKM            0.718667          31.0
# 33          ecfp_prott5_KKM            0.718080          32.0
# 41       maccskeys_esm2_KKM            0.717830          33.0
# 9       molgen_prollama_KKM            0.717367          34.0
# 4     smitrans_prollama_KKM            0.715617          35.0
# 29  chemberta2_prollama_KKM            0.715319          36.0
# 32            ecfp_esmc_KKM            0.714943          37.0
# 30           ecfp_esm1b_KKM            0.708006          38.0
# 38       rdkitfp_prott5_KKM            0.706398          39.0
# 31            ecfp_esm2_KKM            0.702719          40.0
# 39     rdkitfp_prollama_KKM            0.696013          41.0
# 37         rdkitfp_esmc_KKM            0.695103          42.0
# 35        rdkitfp_esm1b_KKM            0.693646          43.0
# 34        ecfp_prollama_KKM            0.691210          44.0
# 36         rdkitfp_esm2_KKM            0.686721          45.0
#
# Key 3:
#                       Model  Mean Value (Key 3)  Rank (Key 3)
# 31            ecfp_esm2_KKM            0.873493           1.0
# 30           ecfp_esm1b_KKM            0.872273           2.0
# 32            ecfp_esmc_KKM            0.863392           3.0
# 15       unimolv1_esm1b_KKM            0.863263           4.0
# 5          molgen_esm1b_KKM            0.861450           5.0
# 25     chemberta2_esm1b_KKM            0.861353           6.0
# 26      chemberta2_esm2_KKM            0.861330           7.0
# 20       unimolv2_esm1b_KKM            0.859083           8.0
# 27      chemberta2_esmc_KKM            0.858958           9.0
# 16        unimolv1_esm2_KKM            0.856678          10.0
# 33          ecfp_prott5_KKM            0.856621          11.0
# 7           molgen_esmc_KKM            0.856283          12.0
# 10       molebert_esm1b_KKM            0.856206          13.0
# 37         rdkitfp_esmc_KKM            0.856003          14.0
# 12        molebert_esmc_KKM            0.855874          15.0
# 17        unimolv1_esmc_KKM            0.855533          16.0
# 11        molebert_esm2_KKM            0.854495          17.0
# 22        unimolv2_esmc_KKM            0.853967          18.0
# 21        unimolv2_esm2_KKM            0.853739          19.0
# 40      maccskeys_esm1b_KKM            0.852892          20.0
# 8         molgen_prott5_KKM            0.852102          21.0
# 23      unimolv2_prott5_KKM            0.851877          22.0
# 2         smitrans_esmc_KKM            0.850860          23.0
# 6           molgen_esm2_KKM            0.850758          24.0
# 13      molebert_prott5_KKM            0.850048          25.0
# 18      unimolv1_prott5_KKM            0.848633          26.0
# 35        rdkitfp_esm1b_KKM            0.847998          27.0
# 28    chemberta2_prott5_KKM            0.846836          28.0
# 41       maccskeys_esm2_KKM            0.846522          29.0
# 1         smitrans_esm2_KKM            0.846291          30.0
# 0        smitrans_esm1b_KKM            0.846142          31.0
# 36         rdkitfp_esm2_KKM            0.844108          32.0
# 43     maccskeys_prott5_KKM            0.843211          33.0
# 42       maccskeys_esmc_KKM            0.842780          34.0
# 3       smitrans_prott5_KKM            0.839464          35.0
# 38       rdkitfp_prott5_KKM            0.829657          36.0
# 29  chemberta2_prollama_KKM            0.794351          37.0
# 19    unimolv1_prollama_KKM            0.786272          38.0
# 9       molgen_prollama_KKM            0.783151          39.0
# 34        ecfp_prollama_KKM            0.781263          40.0
# 24    unimolv2_prollama_KKM            0.774937          41.0
# 14    molebert_prollama_KKM            0.773009          42.0
# 4     smitrans_prollama_KKM            0.767379          43.0
# 39     rdkitfp_prollama_KKM            0.757436          44.0
# 44   maccskeys_prollama_KKM            0.750983          45.0
#
# Key 4:
#                       Model  Mean Value (Key 4)  Rank (Key 4)
# 41       maccskeys_esm2_KKM            0.725311           1.0
# 43     maccskeys_prott5_KKM            0.716980           2.0
# 40      maccskeys_esm1b_KKM            0.715885           3.0
# 42       maccskeys_esmc_KKM            0.708155           4.0
# 10       molebert_esm1b_KKM            0.703553           5.0
# 1         smitrans_esm2_KKM            0.698618           6.0
# 2         smitrans_esmc_KKM            0.695904           7.0
# 13      molebert_prott5_KKM            0.694058           8.0
# 12        molebert_esmc_KKM            0.692649           9.0
# 11        molebert_esm2_KKM            0.689617          10.0
# 3       smitrans_prott5_KKM            0.689502          11.0
# 37         rdkitfp_esmc_KKM            0.686392          12.0
# 38       rdkitfp_prott5_KKM            0.684211          13.0
# 7           molgen_esmc_KKM            0.682859          14.0
# 27      chemberta2_esmc_KKM            0.681649          15.0
# 22        unimolv2_esmc_KKM            0.679796          16.0
# 15       unimolv1_esm1b_KKM            0.678116          17.0
# 35        rdkitfp_esm1b_KKM            0.676444          18.0
# 18      unimolv1_prott5_KKM            0.675133          19.0
# 44   maccskeys_prollama_KKM            0.672176          20.0
# 25     chemberta2_esm1b_KKM            0.671271          21.0
# 0        smitrans_esm1b_KKM            0.667352          22.0
# 21        unimolv2_esm2_KKM            0.665970          23.0
# 6           molgen_esm2_KKM            0.665592          24.0
# 26      chemberta2_esm2_KKM            0.665314          25.0
# 16        unimolv1_esm2_KKM            0.665230          26.0
# 28    chemberta2_prott5_KKM            0.664356          27.0
# 36         rdkitfp_esm2_KKM            0.661880          28.0
# 5          molgen_esm1b_KKM            0.660718          29.0
# 23      unimolv2_prott5_KKM            0.660624          30.0
# 20       unimolv2_esm1b_KKM            0.658985          31.0
# 17        unimolv1_esmc_KKM            0.658972          32.0
# 32            ecfp_esmc_KKM            0.656294          33.0
# 30           ecfp_esm1b_KKM            0.652830          34.0
# 8         molgen_prott5_KKM            0.650745          35.0
# 33          ecfp_prott5_KKM            0.649537          36.0
# 31            ecfp_esm2_KKM            0.641069          37.0
# 4     smitrans_prollama_KKM            0.629535          38.0
# 19    unimolv1_prollama_KKM            0.628018          39.0
# 24    unimolv2_prollama_KKM            0.621093          40.0
# 14    molebert_prollama_KKM            0.619865          41.0
# 39     rdkitfp_prollama_KKM            0.618824          42.0
# 9       molgen_prollama_KKM            0.604219          43.0
# 34        ecfp_prollama_KKM            0.603764          44.0
# 29  chemberta2_prollama_KKM            0.599855          45.0
#
# Key 5:
#                       Model  Mean Value (Key 5)  Rank (Key 5)
# 3       smitrans_prott5_KKM           -0.199419           1.0
# 18      unimolv1_prott5_KKM           -0.216640           2.0
# 44   maccskeys_prollama_KKM           -0.234159           3.0
# 36         rdkitfp_esm2_KKM           -0.237636           4.0
# 42       maccskeys_esmc_KKM           -0.294431           5.0
# 22        unimolv2_esmc_KKM           -0.309372           6.0
# 17        unimolv1_esmc_KKM           -0.316029           7.0
# 19    unimolv1_prollama_KKM           -0.322300           8.0
# 43     maccskeys_prott5_KKM           -0.327970           9.0
# 28    chemberta2_prott5_KKM           -0.376506          10.0
# 23      unimolv2_prott5_KKM           -0.411589          11.0
# 38       rdkitfp_prott5_KKM           -0.431295          12.0
# 0        smitrans_esm1b_KKM           -0.432700          13.0
# 37         rdkitfp_esmc_KKM           -0.435142          14.0
# 13      molebert_prott5_KKM           -0.442255          15.0
# 12        molebert_esmc_KKM           -0.454590          16.0
# 32            ecfp_esmc_KKM           -0.457858          17.0
# 7           molgen_esmc_KKM           -0.489470          18.0
# 30           ecfp_esm1b_KKM           -0.489875          19.0
# 39     rdkitfp_prollama_KKM           -0.492013          20.0
# 33          ecfp_prott5_KKM           -0.502537          21.0
# 8         molgen_prott5_KKM           -0.577942          22.0
# 14    molebert_prollama_KKM           -0.598403          23.0
# 34        ecfp_prollama_KKM           -0.603115          24.0
# 24    unimolv2_prollama_KKM           -0.618969          25.0
# 6           molgen_esm2_KKM           -0.625662          26.0
# 10       molebert_esm1b_KKM           -0.650244          27.0
# 4     smitrans_prollama_KKM           -0.653043          28.0
# 25     chemberta2_esm1b_KKM           -0.665872          29.0
# 40      maccskeys_esm1b_KKM           -0.671291          30.0
# 35        rdkitfp_esm1b_KKM           -0.681260          31.0
# 20       unimolv2_esm1b_KKM           -0.720689          32.0
# 16        unimolv1_esm2_KKM           -0.755427          33.0
# 11        molebert_esm2_KKM           -0.774422          34.0
# 2         smitrans_esmc_KKM           -0.787146          35.0
# 31            ecfp_esm2_KKM           -0.814955          36.0
# 29  chemberta2_prollama_KKM           -0.851040          37.0
# 41       maccskeys_esm2_KKM           -0.854349          38.0
# 15       unimolv1_esm1b_KKM           -0.887211          39.0
# 9       molgen_prollama_KKM           -0.890525          40.0
# 5          molgen_esm1b_KKM           -0.974576          41.0
# 21        unimolv2_esm2_KKM           -1.061041          42.0
# 27      chemberta2_esmc_KKM           -1.161411          43.0
# 1         smitrans_esm2_KKM           -1.177427          44.0
# 26      chemberta2_esm2_KKM           -1.260683          45.0
#
# Key 6:
#                       Model  Mean Value (Key 6)  Rank (Key 6)
# 33          ecfp_prott5_KKM            0.900130           1.0
# 30           ecfp_esm1b_KKM            0.889855           2.0
# 20       unimolv2_esm1b_KKM            0.884893           3.0
# 6           molgen_esm2_KKM            0.884155           4.0
# 23      unimolv2_prott5_KKM            0.882659           5.0
# 21        unimolv2_esm2_KKM            0.879876           6.0
# 16        unimolv1_esm2_KKM            0.876400           7.0
# 10       molebert_esm1b_KKM            0.874162           8.0
# 0        smitrans_esm1b_KKM            0.871411           9.0
# 31            ecfp_esm2_KKM            0.869610          10.0
# 32            ecfp_esmc_KKM            0.868545          11.0
# 28    chemberta2_prott5_KKM            0.865330          12.0
# 15       unimolv1_esm1b_KKM            0.863443          13.0
# 25     chemberta2_esm1b_KKM            0.863023          14.0
# 40      maccskeys_esm1b_KKM            0.862529          15.0
# 7           molgen_esmc_KKM            0.862058          16.0
# 8         molgen_prott5_KKM            0.861026          17.0
# 11        molebert_esm2_KKM            0.860738          18.0
# 18      unimolv1_prott5_KKM            0.854512          19.0
# 13      molebert_prott5_KKM            0.854229          20.0
# 42       maccskeys_esmc_KKM            0.852978          21.0
# 41       maccskeys_esm2_KKM            0.852550          22.0
# 19    unimolv1_prollama_KKM            0.852210          23.0
# 5          molgen_esm1b_KKM            0.851387          24.0
# 12        molebert_esmc_KKM            0.850514          25.0
# 3       smitrans_prott5_KKM            0.850427          26.0
# 1         smitrans_esm2_KKM            0.848419          27.0
# 2         smitrans_esmc_KKM            0.846154          28.0
# 17        unimolv1_esmc_KKM            0.844622          29.0
# 43     maccskeys_prott5_KKM            0.842180          30.0
# 38       rdkitfp_prott5_KKM            0.842090          31.0
# 22        unimolv2_esmc_KKM            0.839446          32.0
# 9       molgen_prollama_KKM            0.839427          33.0
# 27      chemberta2_esmc_KKM            0.837541          34.0
# 35        rdkitfp_esm1b_KKM            0.837398          35.0
# 29  chemberta2_prollama_KKM            0.836998          36.0
# 14    molebert_prollama_KKM            0.836730          37.0
# 24    unimolv2_prollama_KKM            0.835108          38.0
# 34        ecfp_prollama_KKM            0.834105          39.0
# 4     smitrans_prollama_KKM            0.831497          40.0
# 26      chemberta2_esm2_KKM            0.830303          41.0
# 37         rdkitfp_esmc_KKM            0.811042          42.0
# 36         rdkitfp_esm2_KKM            0.795157          43.0
# 39     rdkitfp_prollama_KKM            0.773908          44.0
# 44   maccskeys_prollama_KKM            0.771446          45.0

# %% [markdown]
# wild:

# %%
import pandas as pd

# 定义文件路径
file_paths = {
    'KCAT': {
        'cv0': 'all_result_KCAT_cv0_wild.txt',
        'cv1': 'all_result_KCAT_cv1_wild.txt',
        'cv2': 'all_result_KCAT_cv2_wild.txt',
        'cv3': 'all_result_KCAT_cv3_wild.txt',
        'cv4': 'all_result_KCAT_cv4_wild.txt'
    },
    'KM': {
        'cv0': 'all_result_KM_cv0_wild.txt',
        'cv1': 'all_result_KM_cv1_wild.txt',
        'cv2': 'all_result_KM_cv2_wild.txt',
        'cv3': 'all_result_KM_cv3_wild.txt',
        'cv4': 'all_result_KM_cv4_wild.txt'
    },
    'KKM': {
        'cv0': 'all_result_KKM_cv0_wild.txt',
        'cv1': 'all_result_KKM_cv1_wild.txt',
        'cv2': 'all_result_KKM_cv2_wild.txt',
        'cv3': 'all_result_KKM_cv3_wild.txt',
        'cv4': 'all_result_KKM_cv4_wild.txt'
    }
}

def process_file(file_path, suffix):
    """
    处理单个文件，提取模型名称和R²值，并去掉后缀。
    """
    with open(file_path, 'r') as file:
        lines = file.readlines()

    data = []
    for i in range(0, len(lines), 2):  # 每次跳两行
        model_line = lines[i].strip()  # 模型名称行
        metric_line = lines[i + 1].strip()  # 性能指标行

        # 提取模型名称并去掉后缀
        model_name = model_line.replace('./', '').replace('.csv', '').replace(suffix, '')

        # 提取R²值
        r2_value = None
        r2_index = metric_line.find('r2:')  # 找到'r2:'的位置
        if r2_index != -1:  # 如果找到'r2:'
            r2_str = metric_line[r2_index + 3:].strip()  # 提取'r2:'后面的部分并去掉空格
            if r2_str:  # 检查是否为空字符串
                try:
                    r2_value = float(r2_str)  # 尝试转换为浮点数
                except ValueError:
                    print(f"Warning: Could not convert R² value '{r2_str}' to float for model {model_name}")

        if r2_value is not None:
            data.append((model_name, r2_value))

    # 创建DataFrame
    df = pd.DataFrame(data, columns=['Model', 'R2'])

    return df

# 初始化存储每个类型的 R² 值的字典
type_r2_data = {
    'KCAT': {},
    'KM': {},
    'KKM': {}
}

# 处理每个文件
for file_type, cv_files in file_paths.items():
    for cv, file_path in cv_files.items():
        # 提取后缀（如 '_KCAT'）
        suffix = f'_{file_type}'
        # 处理文件
        df = process_file(file_path, suffix)
        # 将结果存储到 type_r2_data 中
        for _, row in df.iterrows():
            model = row['Model']
            r2 = row['R2']
            if model not in type_r2_data[file_type]:
                type_r2_data[file_type][model] = []
            type_r2_data[file_type][model].append(r2)

# 计算每个类型的 R² 均值并排序
results = {}
for file_type, models_r2 in type_r2_data.items():
    # 计算每个模型的 R² 均值
    mean_r2 = {model: sum(r2_list) / len(r2_list) for model, r2_list in models_r2.items()}
    # 创建 DataFrame
    df_mean_r2 = pd.DataFrame(list(mean_r2.items()), columns=['Model', 'Mean R2'])
    # 按 R² 均值排序并计算排名
    df_mean_r2 = df_mean_r2.sort_values(by='Mean R2', ascending=False)
    df_mean_r2['Rank'] = df_mean_r2['Mean R2'].rank(ascending=False, method='min')
    # 存储结果
    results[file_type] = df_mean_r2

# 打印结果
for file_type, df in results.items():
    print(f"Results for {file_type}:")
    print(df)
    print("\n")
# Out:
# Results for KCAT:
#                   Model   Mean R2  Rank
# 1       molebert_prott5  0.621410   1.0
# 29       molebert_esm1b  0.621166   2.0
# 23        molebert_esm2  0.617258   3.0
# 39        molebert_esmc  0.616782   4.0
# 36          ecfp_prott5  0.613393   5.0
# 21       unimolv1_esm1b  0.613019   6.0
# 33       unimolv2_esm1b  0.611651   7.0
# 27     chemberta2_esm1b  0.611450   8.0
# 34         molgen_esm1b  0.611333   9.0
# 11           ecfp_esm1b  0.609621  10.0
# 7       unimolv2_prott5  0.609571  11.0
# 10    chemberta2_prott5  0.608450  12.0
# 2       unimolv1_prott5  0.607479  13.0
# 42            ecfp_esm2  0.606886  14.0
# 25        unimolv1_esm2  0.606755  15.0
# 4         molgen_prott5  0.606175  16.0
# 32        unimolv2_esmc  0.605992  17.0
# 31        unimolv1_esmc  0.605640  18.0
# 13        unimolv2_esm2  0.605629  19.0
# 18            ecfp_esmc  0.605032  20.0
# 14          molgen_esmc  0.603746  21.0
# 38          molgen_esm2  0.603691  22.0
# 28      chemberta2_esm2  0.603638  23.0
# 41       smitrans_esm1b  0.601882  24.0
# 16      chemberta2_esmc  0.600921  25.0
# 9       smitrans_prott5  0.598366  26.0
# 12        smitrans_esm2  0.596831  27.0
# 37        smitrans_esmc  0.595385  28.0
# 0         rdkitfp_esm1b  0.593008  29.0
# 17         rdkitfp_esm2  0.589772  30.0
# 20       rdkitfp_prott5  0.589036  31.0
# 35         rdkitfp_esmc  0.588945  32.0
# 30    molebert_prollama  0.579789  33.0
# 5       maccskeys_esm1b  0.577847  34.0
# 26     maccskeys_prott5  0.576525  35.0
# 44       maccskeys_esm2  0.572763  36.0
# 43       maccskeys_esmc  0.571280  37.0
# 3         ecfp_prollama  0.561543  38.0
# 22  chemberta2_prollama  0.557967  39.0
# 15    unimolv2_prollama  0.555521  40.0
# 19    unimolv1_prollama  0.555276  41.0
# 6       molgen_prollama  0.547588  42.0
# 8     smitrans_prollama  0.543459  43.0
# 24     rdkitfp_prollama  0.538601  44.0
# 40   maccskeys_prollama  0.527318  45.0
#
#
# Results for KM:
#                   Model   Mean R2  Rank
# 2        unimolv2_esm1b  0.585199   1.0
# 7       unimolv2_prott5  0.582866   2.0
# 28       smitrans_esm1b  0.582689   3.0
# 0        molebert_esm1b  0.582602   4.0
# 25      molebert_prott5  0.580791   5.0
# 30        unimolv2_esm2  0.579774   6.0
# 21         molgen_esm1b  0.578873   7.0
# 23      smitrans_prott5  0.578213   8.0
# 17        molgen_prott5  0.576918   9.0
# 40        molebert_esm2  0.576428  10.0
# 34        smitrans_esm2  0.575901  11.0
# 15     chemberta2_esm1b  0.575592  12.0
# 6           molgen_esm2  0.575339  13.0
# 14       unimolv1_esm1b  0.574677  14.0
# 27      chemberta2_esm2  0.572381  15.0
# 3     chemberta2_prott5  0.572355  16.0
# 9         unimolv2_esmc  0.571867  17.0
# 26      unimolv1_prott5  0.571742  18.0
# 20        molebert_esmc  0.570297  19.0
# 12        unimolv1_esm2  0.570094  20.0
# 24        smitrans_esmc  0.570067  21.0
# 36          molgen_esmc  0.569450  22.0
# 1            ecfp_esm1b  0.564409  23.0
# 11      chemberta2_esmc  0.563282  24.0
# 41        unimolv1_esmc  0.562059  25.0
# 29          ecfp_prott5  0.561135  26.0
# 35            ecfp_esm2  0.555216  27.0
# 16        rdkitfp_esm1b  0.554405  28.0
# 13            ecfp_esmc  0.552320  29.0
# 37    unimolv2_prollama  0.550777  30.0
# 19       rdkitfp_prott5  0.549008  31.0
# 38    smitrans_prollama  0.548512  32.0
# 43      maccskeys_esm1b  0.548462  33.0
# 10    molebert_prollama  0.547138  34.0
# 18     maccskeys_prott5  0.544632  35.0
# 5          rdkitfp_esm2  0.544457  36.0
# 33      molgen_prollama  0.544256  37.0
# 42       maccskeys_esm2  0.542162  38.0
# 22  chemberta2_prollama  0.539068  39.0
# 4     unimolv1_prollama  0.535884  40.0
# 39         rdkitfp_esmc  0.535410  41.0
# 44       maccskeys_esmc  0.533989  42.0
# 32        ecfp_prollama  0.523989  43.0
# 31     rdkitfp_prollama  0.507704  44.0
# 8    maccskeys_prollama  0.502775  45.0
#
#
# Results for KKM:
#                   Model   Mean R2  Rank
# 24       molebert_esm1b  0.532855   1.0
# 9       molebert_prott5  0.532667   2.0
# 27       unimolv1_esm1b  0.529818   3.0
# 12        molebert_esm2  0.528899   4.0
# 40         molgen_esm1b  0.526477   5.0
# 17        molebert_esmc  0.524992   6.0
# 41       unimolv2_esm1b  0.523302   7.0
# 8       unimolv1_prott5  0.522245   8.0
# 37      unimolv2_prott5  0.521818   9.0
# 43        unimolv1_esm2  0.520342  10.0
# 20        molgen_prott5  0.518722  11.0
# 16        unimolv1_esmc  0.517899  12.0
# 6         unimolv2_esm2  0.516582  13.0
# 4           molgen_esmc  0.516337  14.0
# 34          molgen_esm2  0.516133  15.0
# 35        smitrans_esm2  0.514674  16.0
# 30       smitrans_esm1b  0.514596  17.0
# 42      smitrans_prott5  0.514570  18.0
# 19        unimolv2_esmc  0.512498  19.0
# 15        smitrans_esmc  0.511001  20.0
# 39     chemberta2_esm1b  0.509106  21.0
# 7     chemberta2_prott5  0.506965  22.0
# 3       chemberta2_esm2  0.504089  23.0
# 2           ecfp_prott5  0.503264  24.0
# 33      chemberta2_esmc  0.501693  25.0
# 1            ecfp_esm1b  0.500627  26.0
# 38    molebert_prollama  0.496710  27.0
# 11            ecfp_esmc  0.494906  28.0
# 21            ecfp_esm2  0.493801  29.0
# 32    unimolv1_prollama  0.482175  30.0
# 31      molgen_prollama  0.482034  31.0
# 44       rdkitfp_prott5  0.479528  32.0
# 13    unimolv2_prollama  0.477337  33.0
# 5         rdkitfp_esm1b  0.477070  34.0
# 29     maccskeys_prott5  0.474240  35.0
# 23      maccskeys_esm1b  0.471898  36.0
# 10        ecfp_prollama  0.470513  37.0
# 14         rdkitfp_esm2  0.469710  38.0
# 0     smitrans_prollama  0.468403  39.0
# 28         rdkitfp_esmc  0.468327  40.0
# 36       maccskeys_esm2  0.463487  41.0
# 18  chemberta2_prollama  0.462905  42.0
# 25       maccskeys_esmc  0.460966  43.0
# 22     rdkitfp_prollama  0.442666  44.0
# 26   maccskeys_prollama  0.434137  45.0

# %% [markdown]
# mutant：

# %%
import pandas as pd

# 定义文件路径
file_paths = {
    'KCAT': {
        'cv0': 'all_result_KCAT_cv0_mutant.txt',
        'cv1': 'all_result_KCAT_cv1_mutant.txt',
        'cv2': 'all_result_KCAT_cv2_mutant.txt',
        'cv3': 'all_result_KCAT_cv3_mutant.txt',
        'cv4': 'all_result_KCAT_cv4_mutant.txt'
    },
    'KM': {
        'cv0': 'all_result_KM_cv0_mutant.txt',
        'cv1': 'all_result_KM_cv1_mutant.txt',
        'cv2': 'all_result_KM_cv2_mutant.txt',
        'cv3': 'all_result_KM_cv3_mutant.txt',
        'cv4': 'all_result_KM_cv4_mutant.txt'
    },
    'KKM': {
        'cv0': 'all_result_KKM_cv0_mutant.txt',
        'cv1': 'all_result_KKM_cv1_mutant.txt',
        'cv2': 'all_result_KKM_cv2_mutant.txt',
        'cv3': 'all_result_KKM_cv3_mutant.txt',
        'cv4': 'all_result_KKM_cv4_mutant.txt'
    }
}

def process_file(file_path, suffix):
    """
    处理单个文件，提取模型名称和R²值，并去掉后缀。
    """
    with open(file_path, 'r') as file:
        lines = file.readlines()

    data = []
    for i in range(0, len(lines), 2):  # 每次跳两行
        model_line = lines[i].strip()  # 模型名称行
        metric_line = lines[i + 1].strip()  # 性能指标行

        # 提取模型名称并去掉后缀
        model_name = model_line.replace('./', '').replace('.csv', '').replace(suffix, '')

        # 提取R²值
        r2_value = None
        r2_index = metric_line.find('r2:')  # 找到'r2:'的位置
        if r2_index != -1:  # 如果找到'r2:'
            r2_str = metric_line[r2_index + 3:].strip()  # 提取'r2:'后面的部分并去掉空格
            if r2_str:  # 检查是否为空字符串
                try:
                    r2_value = float(r2_str)  # 尝试转换为浮点数
                except ValueError:
                    print(f"Warning: Could not convert R² value '{r2_str}' to float for model {model_name}")

        if r2_value is not None:
            data.append((model_name, r2_value))

    # 创建DataFrame
    df = pd.DataFrame(data, columns=['Model', 'R2'])

    return df

# 初始化存储每个类型的 R² 值的字典
type_r2_data = {
    'KCAT': {},
    'KM': {},
    'KKM': {}
}

# 处理每个文件
for file_type, cv_files in file_paths.items():
    for cv, file_path in cv_files.items():
        # 提取后缀（如 '_KCAT'）
        suffix = f'_{file_type}'
        # 处理文件
        df = process_file(file_path, suffix)
        # 将结果存储到 type_r2_data 中
        for _, row in df.iterrows():
            model = row['Model']
            r2 = row['R2']
            if model not in type_r2_data[file_type]:
                type_r2_data[file_type][model] = []
            type_r2_data[file_type][model].append(r2)

# 计算每个类型的 R² 均值并排序
results = {}
for file_type, models_r2 in type_r2_data.items():
    # 计算每个模型的 R² 均值
    mean_r2 = {model: sum(r2_list) / len(r2_list) for model, r2_list in models_r2.items()}
    # 创建 DataFrame
    df_mean_r2 = pd.DataFrame(list(mean_r2.items()), columns=['Model', 'Mean R2'])
    # 按 R² 均值排序并计算排名
    df_mean_r2 = df_mean_r2.sort_values(by='Mean R2', ascending=False)
    df_mean_r2['Rank'] = df_mean_r2['Mean R2'].rank(ascending=False, method='min')
    # 存储结果
    results[file_type] = df_mean_r2

# 打印结果
for file_type, df in results.items():
    print(f"Results for {file_type}:")
    print(df)
    print("\n")
# Out:
# Results for KCAT:
#                   Model   Mean R2  Rank
# 32        unimolv2_esmc  0.769704   1.0
# 16      chemberta2_esmc  0.764432   2.0
# 14          molgen_esmc  0.760403   3.0
# 7       unimolv2_prott5  0.760116   4.0
# 10    chemberta2_prott5  0.757208   5.0
# 13        unimolv2_esm2  0.756856   6.0
# 37        smitrans_esmc  0.756657   7.0
# 31        unimolv1_esmc  0.754538   8.0
# 33       unimolv2_esm1b  0.752927   9.0
# 28      chemberta2_esm2  0.752246  10.0
# 18            ecfp_esmc  0.752055  11.0
# 27     chemberta2_esm1b  0.749531  12.0
# 38          molgen_esm2  0.747543  13.0
# 39        molebert_esmc  0.747537  14.0
# 4         molgen_prott5  0.747478  15.0
# 36          ecfp_prott5  0.746848  16.0
# 9       smitrans_prott5  0.745533  17.0
# 2       unimolv1_prott5  0.744858  18.0
# 12        smitrans_esm2  0.743756  19.0
# 34         molgen_esm1b  0.743625  20.0
# 25        unimolv1_esm2  0.742260  21.0
# 42            ecfp_esm2  0.742257  22.0
# 1       molebert_prott5  0.739717  23.0
# 41       smitrans_esm1b  0.739446  24.0
# 21       unimolv1_esm1b  0.739214  25.0
# 11           ecfp_esm1b  0.738886  26.0
# 23        molebert_esm2  0.736762  27.0
# 35         rdkitfp_esmc  0.732486  28.0
# 29       molebert_esm1b  0.732153  29.0
# 43       maccskeys_esmc  0.728570  30.0
# 20       rdkitfp_prott5  0.723186  31.0
# 26     maccskeys_prott5  0.722452  32.0
# 17         rdkitfp_esm2  0.718995  33.0
# 44       maccskeys_esm2  0.717029  34.0
# 0         rdkitfp_esm1b  0.715642  35.0
# 5       maccskeys_esm1b  0.714907  36.0
# 15    unimolv2_prollama  0.704331  37.0
# 22  chemberta2_prollama  0.699223  38.0
# 3         ecfp_prollama  0.694216  39.0
# 30    molebert_prollama  0.693853  40.0
# 19    unimolv1_prollama  0.689860  41.0
# 6       molgen_prollama  0.688220  42.0
# 8     smitrans_prollama  0.686069  43.0
# 24     rdkitfp_prollama  0.672776  44.0
# 40   maccskeys_prollama  0.666131  45.0
#
#
# Results for KM:
#                   Model   Mean R2  Rank
# 7       unimolv2_prott5  0.810113   1.0
# 17        molgen_prott5  0.809599   2.0
# 23      smitrans_prott5  0.809475   3.0
# 26      unimolv1_prott5  0.809303   4.0
# 41        unimolv1_esmc  0.808804   5.0
# 24        smitrans_esmc  0.808319   6.0
# 36          molgen_esmc  0.807519   7.0
# 3     chemberta2_prott5  0.807515   8.0
# 9         unimolv2_esmc  0.807026   9.0
# 11      chemberta2_esmc  0.805973  10.0
# 25      molebert_prott5  0.804258  11.0
# 6           molgen_esm2  0.803795  12.0
# 30        unimolv2_esm2  0.802938  13.0
# 12        unimolv1_esm2  0.802695  14.0
# 2        unimolv2_esm1b  0.802449  15.0
# 20        molebert_esmc  0.802432  16.0
# 34        smitrans_esm2  0.802297  17.0
# 28       smitrans_esm1b  0.802265  18.0
# 14       unimolv1_esm1b  0.802124  19.0
# 21         molgen_esm1b  0.801595  20.0
# 15     chemberta2_esm1b  0.800909  21.0
# 27      chemberta2_esm2  0.800806  22.0
# 29          ecfp_prott5  0.799041  23.0
# 40        molebert_esm2  0.798388  24.0
# 0        molebert_esm1b  0.797025  25.0
# 13            ecfp_esmc  0.795746  26.0
# 35            ecfp_esm2  0.795534  27.0
# 1            ecfp_esm1b  0.792284  28.0
# 19       rdkitfp_prott5  0.791756  29.0
# 18     maccskeys_prott5  0.791712  30.0
# 38    smitrans_prollama  0.789739  31.0
# 33      molgen_prollama  0.789502  32.0
# 39         rdkitfp_esmc  0.788546  33.0
# 4     unimolv1_prollama  0.787615  34.0
# 42       maccskeys_esm2  0.787357  35.0
# 22  chemberta2_prollama  0.787044  36.0
# 37    unimolv2_prollama  0.786901  37.0
# 44       maccskeys_esmc  0.785308  38.0
# 43      maccskeys_esm1b  0.784706  39.0
# 5          rdkitfp_esm2  0.784401  40.0
# 16        rdkitfp_esm1b  0.783171  41.0
# 10    molebert_prollama  0.782140  42.0
# 32        ecfp_prollama  0.768030  43.0
# 31     rdkitfp_prollama  0.763106  44.0
# 8    maccskeys_prollama  0.757595  45.0
#
#
# Results for KKM:
#                   Model   Mean R2  Rank
# 16        unimolv1_esmc  0.692569   1.0
# 20        molgen_prott5  0.691458   2.0
# 8       unimolv1_prott5  0.691173   3.0
# 37      unimolv2_prott5  0.690712   4.0
# 15        smitrans_esmc  0.689322   5.0
# 4           molgen_esmc  0.688851   6.0
# 17        molebert_esmc  0.688646   7.0
# 19        unimolv2_esmc  0.687358   8.0
# 9       molebert_prott5  0.686203   9.0
# 43        unimolv1_esm2  0.685030  10.0
# 42      smitrans_prott5  0.684516  11.0
# 7     chemberta2_prott5  0.682729  12.0
# 33      chemberta2_esmc  0.682572  13.0
# 6         unimolv2_esm2  0.681069  14.0
# 27       unimolv1_esm1b  0.680210  15.0
# 41       unimolv2_esm1b  0.679933  16.0
# 40         molgen_esm1b  0.679650  17.0
# 34          molgen_esm2  0.679211  18.0
# 12        molebert_esm2  0.676611  19.0
# 24       molebert_esm1b  0.676346  20.0
# 35        smitrans_esm2  0.676189  21.0
# 29     maccskeys_prott5  0.675981  22.0
# 3       chemberta2_esm2  0.675183  23.0
# 30       smitrans_esm1b  0.674653  24.0
# 2           ecfp_prott5  0.673135  25.0
# 25       maccskeys_esmc  0.671976  26.0
# 39     chemberta2_esm1b  0.670637  27.0
# 44       rdkitfp_prott5  0.668320  28.0
# 11            ecfp_esmc  0.666582  29.0
# 1            ecfp_esm1b  0.665390  30.0
# 23      maccskeys_esm1b  0.664885  31.0
# 21            ecfp_esm2  0.663939  32.0
# 28         rdkitfp_esmc  0.662484  33.0
# 36       maccskeys_esm2  0.661989  34.0
# 14         rdkitfp_esm2  0.657291  35.0
# 5         rdkitfp_esm1b  0.654581  36.0
# 32    unimolv1_prollama  0.633162  37.0
# 31      molgen_prollama  0.632142  38.0
# 13    unimolv2_prollama  0.630895  39.0
# 38    molebert_prollama  0.630599  40.0
# 0     smitrans_prollama  0.628823  41.0
# 18  chemberta2_prollama  0.618538  42.0
# 26   maccskeys_prollama  0.612538  43.0
# 10        ecfp_prollama  0.600252  44.0
# 22     rdkitfp_prollama  0.595775  45.0
