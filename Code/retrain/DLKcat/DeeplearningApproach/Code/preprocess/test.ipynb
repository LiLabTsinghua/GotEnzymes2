# %%
import json

# Read the JSON file
with open('/home/wuke/project/bio_deeplearning/AIenzyme/code/structure/DLKcat/DeeplearningApproach/Data/database/Kcat_combination_0918_wildtype_mutant.json', 'r') as file:
    data = json.load(file)
i = 0
for kcat_data in data:
# Count the number of empty values
    Sequence = kcat_data['Sequence']
    if len(Sequence)> 1000:
        i=i+1
print(i)
# Out:
# 655
