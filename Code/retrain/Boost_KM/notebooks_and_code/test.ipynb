# %%
import pandas as pd
import pickle
import os

datasets_dir = "../datasets"
data = pickle.load(open(os.path.join(datasets_dir, "splits", "test_data.pkl"), "rb"))
data
# Out:
#       KEGG ID                                             Unirep  \
# 427    C00392  [0.0053117466, 0.05196901, 0.057307187, -0.048...
# 2657   C00042  [0.005964753000000001, 0.01036435, 0.094908446...
# 5861   C00149  [0.012431591, -0.065737695, 0.15152687, -0.007...
# 3883   C00004  [0.02332337, -0.12623736, 0.07419281, -0.02490...
# 4495   C00301  [0.0054127527000000005, 0.13620791, 0.10213430...
# ...       ...                                                ...
# 6464   C00441  [0.024351604, 0.35456434, 0.023826605, -0.1048...
# 11155  C00003  [0.032796238, 0.09108182, 0.10760366, -0.03496...
# 9277   C00323  [0.0044775507, -0.03616925, 0.036295366, -0.01...
# 10529  C00015  [0.0032914095, 0.03939328, 0.08582278, -0.0328...
# 7538   C00011  [0.00589887, 0.083098516, 0.08199989999999999,...
#
#                                                     ECFP  \
# 427    0100000000000000000000000000000000000000000000...
# 2657   0000000000000000000000000000000000000000000000...
# ...
